# %%
import numpy as np
import random
from sklearn.manifold import TSNE
random.seed(1)
a = np.random.uniform(size=(100,20))
TSNE(n_components=2).fit_transform(a)
# Out:
# array([[  0.52668136,  -3.92829418],
#        [ -2.56846237,  -6.46815252],
#        [  1.17276788,  -6.42741632],
#        [ -4.07270193,  -5.67396402],
#        [ -7.5665307 ,  -6.34139013],
#        [ -0.47085068,  -4.63891029],
#        [ -1.71154439,  -4.20771027],
#        [ -3.52468467,  -7.20726824],
#        [ -7.82220411,  -2.78119898],
#        [ -5.22724152,  -5.23147583],
#        [ -7.4118638 ,  -2.6552844 ],
#        [ -5.21997738,  -4.48451185],
#        [ -1.92770243,  -5.39382744],
#        [ -5.90995836,  -1.44533718],
#        [  0.14002302,  -5.44780493],
#        [ -6.32699251,  -7.3941617 ],
#        [ -0.97040731,  -8.14661694],
#        [ -9.05321217,  -3.89338613],
#        [  1.0625788 ,  -4.07813501],
#        [ -0.99383718,  -6.82794476],
#        [ -5.63690996,  -3.85542011],
#        [ -2.3187027 ,  -3.64357901],
#        [ -3.05415606,  -1.16163933],
#        [ -5.13705587, -10.01955605],
#        [ -7.65509939,  -1.52827978],
# ...
