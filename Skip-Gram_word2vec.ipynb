# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-05
counts = Counter(int_words)
total_count = len(int_words)
freq = {word: count/total_count for word, count in counts.items()}
## If P_drop = 1-np.sqrt(t/f), then P_keep is np.sqrt(t/fs) 
keep = {ii: (random.random()<np.sqrt(threshold/ff)) for ii,ff in freq.items()}
train_words = [ii for ii in int_words if keep[ii]] # The final subsampled word list

# %%
print("Total words: {}".format(len(train_words)))
print("Unique words: {}".format(len(set(train_words))))
# Out:
# Total words: 4391520
# Unique words: 60517

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    random_size = np.random.randint(1, window_size + 1)
    start = idx-random_size if (idx-random_size)>0 else 0 # if at the beginning of words
    # TODO Does this return a deep copy of the list, and, so, is it necessary?
    return list(set(words[start : idx] + words[idx + 1 : idx + random_size + 1]))

# %%
neibs = get_target(words, 3)
print(words[3], neibs)
# Out:
# a ['term', 'originated', 'of', 'as']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix, i.e. _the weights between the inputs and the hidden layer_, to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.3493 0.1847 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.2737 0.1965 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1714 0.2096 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.2003 0.2109 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1074 0.2121 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.1345 0.1995 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0853 0.1963 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.9553 0.1982 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.8325 0.1989 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.7543 0.1990 sec/batch
# Nearest to war: machiavellian, gabaa, rosamund, scholarships, flores, simplifies, disagree, gelre,
# Nearest to years: nahash, november, financially, gottlieb, acknowledged, crete, dft, commutative,
# Nearest to four: throttled, rediscovered, civilised, condominiums, augmentation, inversion, watershed, scapegoat,
# Nearest to had: russia, cournot, ser, blowing, animist, husayni, grasps, mifune,
# Nearest to were: korah, rediscovery, paratrooper, flo, injustice, clarified, duffy, pwn,
# Nearest to it: citation, reconstruction, loar, frustrating, heracleidae, terengganu, farts, millicent,
# Nearest to be: disaffection, assigned, paran, def, monteagle, niger, wobbly, sweetened,
# Nearest to system: incredibly, tang, orbited, hauling, snakes, itch, valverde, jad,
# Nearest to prince: asu, stubborn, liturgical, pills, ontological, swing, choosing, enabled,
# Nearest to heavy: ksi, teborg, diego, bump, edt, atx, availible, robustness,
# Nearest to issue: transitory, antichrist, excesses, wernicke, misbehavior, respectively, albicans, nadir,
# Nearest to instance: handy, connery, garibaldi, schedules, usb, compl, mcgee, power,
# Nearest to something: michelangelo, cristae, reidel, chloramine, caucus, campesinos, mais, busway,
# Nearest to pre: ob, subjectively, turismo, mannerist, oau, registered, molars, elevators,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nigra, decisively, subdominant, teal,
# Nearest to accepted: beringer, duke, doctoral, lasts, embankments, remaining, ecole, bubiyan,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.6564 0.2033 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.5158 0.2000 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.4939 0.2003 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.4283 0.2011 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.3731 0.2009 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.3374 0.2024 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.2971 0.2023 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.2754 0.2008 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.2402 0.2026 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.1431 0.2018 sec/batch
# Nearest to war: machiavellian, gabaa, scholarships, rosamund, flores, reserves, revenues, simplifies,
# Nearest to years: nahash, november, financially, gottlieb, acknowledged, welling, crete, dft,
# Nearest to four: throttled, rediscovered, civilised, condominiums, inversion, watershed, augmentation, latinate,
# Nearest to had: russia, cournot, blowing, ser, husayni, animist, grasps, mifune,
# Nearest to were: korah, rediscovery, paratrooper, flo, injustice, clarified, duffy, pwn,
# Nearest to it: citation, reconstruction, loar, frustrating, heracleidae, draught, terengganu, potash,
# Nearest to be: disaffection, paran, assigned, peer, def, sweetened, intensified, monteagle,
# Nearest to system: incredibly, tang, orbited, snakes, hauling, radios, itch, valverde,
# Nearest to prince: liturgical, asu, stubborn, ontological, enabled, swing, foraging, pills,
# Nearest to heavy: ksi, teborg, diego, bump, edt, atx, availible, hardening,
# Nearest to issue: transitory, antichrist, excesses, wernicke, albicans, misbehavior, dominate, nadir,
# Nearest to instance: handy, connery, usb, garibaldi, contrasting, schedules, subordinate, cooking,
# Nearest to something: michelangelo, reidel, cristae, chloramine, caucus, campesinos, mais, busway,
# Nearest to pre: ob, subjectively, turismo, mannerist, registered, molars, elevators, party,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nigra, subdominant, nitrites, tbm,
# Nearest to accepted: doctoral, lasts, duke, beringer, disorder, ecole, embankments, hostile,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.2284 0.2045 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.1794 0.2026 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.1639 0.2038 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.1276 0.2008 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.0812 0.2019 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.0858 0.2035 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.0823 0.2013 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.0968 0.2025 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.0900 0.2028 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.1217 0.2040 sec/batch
# Nearest to war: machiavellian, gabaa, rosamund, scholarships, reserves, flores, revenues, simplifies,
# Nearest to years: nahash, november, financially, acknowledged, gottlieb, welling, crete, novum,
# Nearest to four: throttled, civilised, rediscovered, condominiums, watershed, inversion, latinate, augmentation,
# Nearest to had: russia, cournot, blowing, ser, husayni, mifune, awt, xmas,
# Nearest to were: korah, paratrooper, flo, rediscovery, clarified, injustice, duffy, pwn,
# Nearest to it: citation, loar, reconstruction, heracleidae, potash, terengganu, draught, jeux,
# Nearest to be: disaffection, def, monteagle, paran, sweetened, peer, intensified, wobbly,
# Nearest to system: incredibly, orbited, tang, snakes, hauling, itch, radios, valverde,
# Nearest to prince: asu, stubborn, liturgical, ontological, welch, czi, swing, foraging,
# Nearest to heavy: ksi, teborg, diego, availible, bump, atx, edt, robustness,
# Nearest to issue: transitory, excesses, antichrist, misbehavior, exemplar, albicans, encode, oatmeal,
# Nearest to instance: handy, connery, usb, garibaldi, subordinate, schedules, lieber, compl,
# Nearest to something: cristae, reidel, michelangelo, chloramine, caucus, campesinos, busway, svoboda,
# Nearest to pre: ob, subjectively, turismo, mannerist, molars, registered, party, elevators,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, subdominant, nigra, nitrites, tbm,
# Nearest to accepted: doctoral, lasts, ecole, beringer, embankments, pratt, duke, hostile,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.0165 0.2070 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.0128 0.2035 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 3.9885 0.2047 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.0398 0.2131 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.0277 0.2060 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.0642 0.2145 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 3.9964 0.2079 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 3.9228 0.2043 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 3.9970 0.2039 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 3.8958 0.2037 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, rosamund, revenues, scholarships, flores, simplifies,
# Nearest to years: nahash, november, financially, acknowledged, gottlieb, novum, kochi, crete,
# Nearest to four: throttled, civilised, rediscovered, condominiums, watershed, augmentation, latinate, inversion,
# Nearest to had: russia, cournot, blowing, ser, mifune, husayni, hsieh, grasps,
# Nearest to were: korah, paratrooper, flo, injustice, clarified, rediscovery, duffy, pwn,
# Nearest to it: citation, loar, reconstruction, potash, heracleidae, terengganu, draught, annex,
# Nearest to be: disaffection, monteagle, peer, wobbly, paran, def, sweetened, assigned,
# Nearest to system: orbited, incredibly, tang, snakes, hauling, itch, radios, valverde,
# Nearest to prince: asu, stubborn, liturgical, welch, brooklyn, selim, ontological, concerto,
# Nearest to heavy: ksi, teborg, diego, bump, atx, mixed, availible, robustness,
# Nearest to issue: transitory, exemplar, excesses, antichrist, misbehavior, encode, albicans, dominate,
# Nearest to instance: handy, connery, usb, garibaldi, valentinius, contrasting, schedules, compl,
# Nearest to something: cristae, reidel, michelangelo, chloramine, caucus, campesinos, ils, svoboda,
# Nearest to pre: ob, subjectively, turismo, mannerist, registered, bid, molars, party,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nitrites, tbm, subdominant, teal,
# Nearest to accepted: doctoral, bubiyan, beringer, ecole, embankments, lasts, hostile, duke,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 3.9244 0.2095 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 3.9565 0.2042 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 3.9481 0.2028 sec/batch
# Epoch 2/10 Iteration: 4400 Avg. Training loss: 3.9184 0.0177 sec/batch
# Epoch 2/10 Iteration: 4500 Avg. Training loss: 3.8807 0.1947 sec/batch
# Epoch 2/10 Iteration: 4600 Avg. Training loss: 3.8768 0.1951 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 3.8470 0.1969 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 3.8106 0.1952 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 3.8252 0.1944 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 3.7882 0.1947 sec/batch
# Nearest to war: machiavellian, reserves, gabaa, rosamund, revenues, flores, scholarships, simplifies,
# Nearest to years: nahash, november, financially, acknowledged, novum, kochi, crete, gottlieb,
# Nearest to four: throttled, civilised, watershed, rediscovered, condominiums, latinate, augmentation, roared,
# Nearest to had: russia, cournot, ser, blowing, husayni, mifune, hsieh, lder,
# Nearest to were: korah, paratrooper, rediscovery, injustice, flo, clarified, duffy, pwn,
# Nearest to it: citation, loar, reconstruction, potash, heracleidae, terengganu, draught, middleware,
# Nearest to be: disaffection, monteagle, peer, wobbly, def, paran, intensified, cytokines,
# Nearest to system: orbited, incredibly, tang, snakes, hauling, itch, radios, jad,
# Nearest to prince: asu, stubborn, brooklyn, selim, maria, welch, liturgical, czi,
# Nearest to heavy: ksi, teborg, diego, mixed, atx, bump, availible, robustness,
# Nearest to issue: transitory, noi, encode, antichrist, exemplar, albicans, misbehavior, bpo,
# Nearest to instance: handy, connery, usb, garibaldi, compl, valentinius, subordinate, physics,
# Nearest to something: cristae, reidel, michelangelo, chloramine, caucus, campesinos, svoboda, busway,
# Nearest to pre: ob, subjectively, turismo, mannerist, registered, molars, laker, cesare,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nitrites, tbm, nigra, subdominant,
# Nearest to accepted: doctoral, bubiyan, beringer, hostile, ecole, embankments, confidant, spit,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 3.7499 0.1952 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 3.8011 0.1937 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 3.7820 0.1934 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 3.7740 0.1947 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 3.6789 0.1957 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 3.7272 0.1933 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 3.7652 0.1913 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 3.7559 0.1943 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 3.7617 0.1932 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 3.7410 0.1935 sec/batch
# Nearest to war: machiavellian, reserves, gabaa, revenues, rosamund, flores, scholarships, simplifies,
# Nearest to years: nahash, november, financially, acknowledged, kochi, novum, crete, welling,
# Nearest to four: civilised, throttled, condominiums, watershed, rediscovered, roared, augmentation, latinate,
# Nearest to had: russia, cournot, blowing, ser, husayni, mifune, hsieh, lder,
# Nearest to were: paratrooper, rediscovery, korah, clarified, flo, injustice, pwn, duffy,
# Nearest to it: citation, loar, reconstruction, potash, heracleidae, draught, terengganu, middleware,
# Nearest to be: disaffection, peer, monteagle, paran, wobbly, def, cytokines, intensified,
# Nearest to system: orbited, incredibly, tang, itch, snakes, hauling, radios, valverde,
# Nearest to prince: asu, stubborn, brooklyn, selim, liturgical, schlegel, czi, concerto,
# Nearest to heavy: ksi, teborg, diego, mixed, atx, bump, availible, robustness,
# Nearest to issue: transitory, encode, noi, chronologically, albicans, antichrist, bpo, exemplar,
# Nearest to instance: handy, usb, connery, garibaldi, valentinius, schedules, deckers, physics,
# Nearest to something: reidel, cristae, michelangelo, chloramine, busway, caucus, ils, svoboda,
# Nearest to pre: ob, subjectively, turismo, mannerist, registered, cesare, laker, molars,
# Nearest to construction: rosenbaum, chondrite, remarried, nitrites, whitby, subdominant, nigra, teal,
# Nearest to accepted: doctoral, bubiyan, ecole, hostile, embankments, beringer, lasts, confidant,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 3.7195 0.1980 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 3.7425 0.1937 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 3.7443 0.1941 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 3.6775 0.1922 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 3.7177 0.1930 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 3.6829 0.1935 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 3.7106 0.1949 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 3.7135 0.1942 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 3.6290 0.1944 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 3.6875 0.1942 sec/batch
# Nearest to war: reserves, machiavellian, gabaa, revenues, flores, rosamund, scholarships, simplifies,
# Nearest to years: nahash, november, financially, acknowledged, kochi, irving, gottlieb, crete,
# Nearest to four: civilised, throttled, watershed, condominiums, rediscovered, roared, augmentation, latinate,
# Nearest to had: russia, cournot, ser, blowing, mifune, husayni, hsieh, casualties,
# Nearest to were: paratrooper, rediscovery, korah, clarified, injustice, flo, pwn, duffy,
# Nearest to it: citation, loar, potash, reconstruction, draught, farts, heracleidae, terengganu,
# Nearest to be: disaffection, peer, monteagle, wobbly, intensified, paran, cytokines, def,
# Nearest to system: orbited, incredibly, tang, snakes, itch, hauling, valverde, radios,
# Nearest to prince: asu, stubborn, brooklyn, schlegel, czi, selim, concerto, liturgical,
# Nearest to heavy: ksi, bump, mixed, teborg, atx, diego, availible, robustness,
# Nearest to issue: transitory, chronologically, encode, antichrist, bpo, condemning, exemplar, noi,
# Nearest to instance: handy, connery, usb, schedules, garibaldi, deckers, valentinius, detects,
# Nearest to something: reidel, cristae, michelangelo, chloramine, unmodified, caucus, svoboda, busway,
# Nearest to pre: ob, subjectively, turismo, mannerist, registered, cesare, laker, gubernatorial,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nitrites, subdominant, congresswoman, kirby,
# Nearest to accepted: doctoral, bubiyan, hostile, confidant, ecole, beringer, embankments, remaining,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 3.7427 0.1959 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 3.6616 0.1963 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 3.6918 0.1936 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 3.7345 0.1941 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 3.6095 0.1938 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 3.6246 0.1933 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 3.6534 0.1956 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 3.6741 0.1979 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 3.6768 0.1963 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 3.7240 0.1950 sec/batch
# Nearest to war: machiavellian, reserves, gabaa, revenues, flores, rosamund, simplifies, scholarships,
# Nearest to years: nahash, november, financially, acknowledged, kochi, crete, moll, gottlieb,
# Nearest to four: throttled, civilised, watershed, condominiums, augmentation, roared, latinate, rediscovered,
# Nearest to had: russia, cournot, mifune, ser, blowing, husayni, hsieh, od,
# Nearest to were: paratrooper, clarified, korah, rediscovery, injustice, flo, pwn, fraenkel,
# Nearest to it: citation, loar, potash, reconstruction, heracleidae, draught, terengganu, farts,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, paran, cytokines, astronautics,
# Nearest to system: orbited, incredibly, tang, itch, snakes, hauling, valverde, adb,
# Nearest to prince: asu, stubborn, schlegel, brooklyn, siddha, czi, concerto, selim,
# Nearest to heavy: ksi, atx, bump, mixed, teborg, availible, diego, robustness,
# Nearest to issue: transitory, antichrist, condemning, bpo, exemplar, albicans, popper, chronologically,
# Nearest to instance: handy, connery, usb, schedules, garibaldi, valentinius, detects, subordinate,
# Nearest to something: reidel, cristae, michelangelo, chloramine, monochrome, unmodified, caucus, busway,
# Nearest to pre: ob, subjectively, turismo, mannerist, papuan, registered, bid, fearless,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, ignacy, nitrites, congresswoman, subdominant,
# Nearest to accepted: bubiyan, doctoral, confidant, hostile, ecole, beringer, duke, embankments,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 3.6457 0.1964 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.5806 0.1935 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 3.6894 0.1929 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 3.5285 0.1921 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 3.5970 0.1954 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.6081 0.1947 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.6396 0.1943 sec/batch
# Epoch 3/10 Iteration: 8800 Avg. Training loss: 3.7185 0.0351 sec/batch
# Epoch 3/10 Iteration: 8900 Avg. Training loss: 3.5863 0.1942 sec/batch
# Epoch 3/10 Iteration: 9000 Avg. Training loss: 3.5726 0.1967 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, revenues, flores, rosamund, simplifies, srinagar,
# Nearest to years: nahash, november, financially, acknowledged, kochi, crete, welling, vah,
# Nearest to four: throttled, civilised, watershed, condominiums, augmentation, roared, rediscovered, latinate,
# Nearest to had: russia, cournot, mifune, blowing, ser, husayni, hsieh, od,
# Nearest to were: paratrooper, injustice, korah, rediscovery, clarified, flo, pwn, theories,
# Nearest to it: citation, potash, loar, reconstruction, heracleidae, draught, farts, terengganu,
# Nearest to be: disaffection, peer, intensified, monteagle, wobbly, paran, cytokines, astronautics,
# Nearest to system: orbited, incredibly, tang, valverde, itch, hauling, snakes, adb,
# Nearest to prince: asu, stubborn, schlegel, brooklyn, siddha, czi, concerto, selim,
# Nearest to heavy: ksi, atx, mixed, bump, diego, teborg, availible, robustness,
# Nearest to issue: transitory, condemning, bpo, encode, popper, albicans, noi, antichrist,
# Nearest to instance: handy, usb, connery, schedules, garibaldi, valentinius, detects, deckers,
# Nearest to something: reidel, cristae, michelangelo, chloramine, unmodified, badged, svoboda, monochrome,
# Nearest to pre: ob, subjectively, turismo, mannerist, fearless, papuan, registered, bid,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, ignacy, congresswoman, nitrites, subdominant,
# Nearest to accepted: bubiyan, doctoral, connote, confidant, ecole, hostile, beringer, embankments,
# Epoch 3/10 Iteration: 9100 Avg. Training loss: 3.5428 0.2133 sec/batch
# Epoch 3/10 Iteration: 9200 Avg. Training loss: 3.5166 0.2051 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 3.5217 0.2021 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.5517 0.2008 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.5189 0.2027 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.5734 0.2016 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.5191 0.2066 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.4965 0.2035 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.4027 0.2023 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.4363 0.2036 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, flores, revenues, rosamund, simplifies, srinagar,
# Nearest to years: nahash, november, financially, welling, crete, kochi, acknowledged, vah,
# Nearest to four: throttled, civilised, watershed, condominiums, roared, augmentation, latinate, gendai,
# Nearest to had: russia, cournot, mifune, husayni, blowing, ser, hsieh, od,
# Nearest to were: paratrooper, korah, injustice, rediscovery, clarified, flo, pwn, theories,
# Nearest to it: citation, potash, loar, reconstruction, heracleidae, draught, farts, terengganu,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, cytokines, paran, def,
# Nearest to system: orbited, incredibly, tang, itch, valverde, snakes, adb, hauling,
# Nearest to prince: stubborn, schlegel, asu, siddha, brooklyn, delores, czi, selim,
# Nearest to heavy: ksi, atx, mixed, bump, diego, teborg, availible, curves,
# Nearest to issue: transitory, bpo, encode, exemplar, noi, popper, condemning, antichrist,
# Nearest to instance: handy, usb, connery, schedules, garibaldi, detects, cooking, deckers,
# Nearest to something: reidel, cristae, chloramine, michelangelo, monochrome, unmodified, midway, badged,
# Nearest to pre: ob, subjectively, turismo, mannerist, fearless, papuan, registered, aboriginal,
# Nearest to construction: rosenbaum, chondrite, remarried, whitby, nitrites, congresswoman, subdominant, kirby,
# Nearest to accepted: bubiyan, doctoral, ecole, connote, hostile, beringer, duke, confidant,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.5008 0.2075 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.5342 0.2023 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.4999 0.2051 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.5152 0.2028 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.4628 0.2078 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.5578 0.1984 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.4788 0.1951 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.4857 0.1923 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.5038 0.1949 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.4956 0.1938 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, revenues, flores, rosamund, simplifies, srinagar,
# Nearest to years: nahash, november, financially, welling, kochi, crete, vah, acknowledged,
# Nearest to four: throttled, civilised, watershed, condominiums, roared, augmentation, gendai, scorched,
# Nearest to had: russia, cournot, mifune, husayni, od, blowing, ser, jealous,
# Nearest to were: paratrooper, korah, injustice, rediscovery, clarified, pwn, flo, theories,
# Nearest to it: citation, potash, loar, reconstruction, draught, heracleidae, farts, terengganu,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, cytokines, paran, def,
# Nearest to system: incredibly, orbited, itch, valverde, tang, adb, snakes, hauling,
# Nearest to prince: schlegel, asu, stubborn, siddha, czi, brooklyn, selim, delores,
# Nearest to heavy: ksi, atx, bump, mixed, teborg, diego, availible, robustness,
# Nearest to issue: transitory, condemning, encode, popper, noam, bpo, exemplar, sponsorships,
# Nearest to instance: handy, connery, schedules, usb, garibaldi, deckers, detects, crystallizes,
# Nearest to something: reidel, cristae, chloramine, michelangelo, monochrome, unmodified, midway, badged,
# Nearest to pre: subjectively, ob, turismo, mannerist, papuan, fearless, registered, aboriginal,
# Nearest to construction: rosenbaum, chondrite, remarried, nitrites, congresswoman, whitby, kirby, subdominant,
# Nearest to accepted: doctoral, bubiyan, connote, ecole, beringer, disorder, hostile, duke,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.5276 0.1968 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.5233 0.1930 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.3722 0.1935 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.5216 0.1951 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.5179 0.1937 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.4646 0.1953 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.4546 0.1921 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.5076 0.1946 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.4470 0.1947 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.4477 0.1918 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, flores, revenues, rosamund, simplifies, conservancy,
# Nearest to years: nahash, november, financially, kochi, welling, crete, covert, vah,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, augmentation, scorched, scapegoat,
# Nearest to had: russia, cournot, mifune, husayni, od, jealous, blowing, hsieh,
# Nearest to were: paratrooper, korah, rediscovery, injustice, clarified, pwn, flo, theories,
# Nearest to it: citation, potash, loar, reconstruction, draught, terengganu, farts, annex,
# Nearest to be: disaffection, peer, wobbly, monteagle, intensified, paran, astronautics, trotskyist,
# Nearest to system: incredibly, orbited, itch, valverde, adb, tang, snakes, hauling,
# Nearest to prince: schlegel, czi, stubborn, siddha, asu, selim, brooklyn, delores,
# Nearest to heavy: ksi, atx, bump, diego, mixed, availible, teborg, robustness,
# Nearest to issue: transitory, exemplar, noam, popper, bpo, condemning, encode, antichrist,
# Nearest to instance: handy, connery, schedules, usb, garibaldi, subordinate, deckers, ivorian,
# Nearest to something: reidel, cristae, chloramine, monochrome, yamaha, unmodified, michelangelo, ils,
# Nearest to pre: ob, turismo, subjectively, mannerist, papuan, aboriginal, gubernatorial, registered,
# Nearest to construction: rosenbaum, chondrite, remarried, nitrites, congresswoman, whitby, kirby, enos,
# Nearest to accepted: bubiyan, doctoral, confidant, ecole, connote, fln, disorder, transcaucasian,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.4834 0.1976 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.4964 0.1971 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.5490 0.1953 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.5942 0.1941 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.4802 0.1945 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.5053 0.1936 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.4596 0.1927 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.3236 0.1928 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.4851 0.1969 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.4305 0.1942 sec/batch
# Nearest to war: machiavellian, gabaa, reserves, flores, revenues, rosamund, shikoku, simplifies,
# Nearest to years: nahash, november, financially, welling, crete, vah, kochi, covert,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, augmentation, scapegoat, scorched,
# Nearest to had: russia, cournot, mifune, husayni, od, casualties, jealous, blowing,
# Nearest to were: paratrooper, korah, clarified, injustice, rediscovery, pwn, flo, theories,
# Nearest to it: citation, potash, loar, reconstruction, terengganu, annex, farts, smyth,
# Nearest to be: disaffection, peer, monteagle, intensified, trotskyist, wobbly, astronautics, paran,
# Nearest to system: incredibly, orbited, valverde, adb, itch, estudios, tang, hagerstown,
# Nearest to prince: schlegel, siddha, czi, stubborn, asu, selim, delores, brooklyn,
# Nearest to heavy: atx, ksi, bump, availible, mixed, diego, teborg, robustness,
# Nearest to issue: transitory, popper, exemplar, bpo, noam, locative, encode, sponsorships,
# Nearest to instance: handy, connery, schedules, usb, deckers, detects, valentinius, crystallizes,
# Nearest to something: reidel, cristae, chloramine, yamaha, monochrome, ils, unmodified, busway,
# Nearest to pre: ob, turismo, subjectively, mannerist, aboriginal, papuan, registered, conceding,
# Nearest to construction: rosenbaum, chondrite, remarried, nitrites, congresswoman, whitby, kirby, ignacy,
# Nearest to accepted: doctoral, bubiyan, ecole, connote, fln, beringer, disorder, confidant,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.4834 0.1974 sec/batch
# Epoch 4/10 Iteration: 13200 Avg. Training loss: 3.5208 0.0522 sec/batch
# Epoch 4/10 Iteration: 13300 Avg. Training loss: 3.3944 0.1942 sec/batch
# Epoch 4/10 Iteration: 13400 Avg. Training loss: 3.4139 0.1945 sec/batch
# Epoch 4/10 Iteration: 13500 Avg. Training loss: 3.3751 0.1978 sec/batch
# Epoch 4/10 Iteration: 13600 Avg. Training loss: 3.3744 0.1938 sec/batch
# Epoch 4/10 Iteration: 13700 Avg. Training loss: 3.4012 0.1967 sec/batch
# Epoch 4/10 Iteration: 13800 Avg. Training loss: 3.3962 0.1968 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.3442 0.1928 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.3996 0.1932 sec/batch
# Nearest to war: machiavellian, gabaa, flores, reserves, revenues, rosamund, shikoku, simplifies,
# Nearest to years: nahash, november, financially, welling, crete, vah, kochi, covert,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, augmentation, scapegoat, scorched,
# Nearest to had: russia, cournot, mifune, husayni, od, casualties, blowing, integrate,
# Nearest to were: paratrooper, korah, rediscovery, injustice, clarified, pwn, flo, theories,
# Nearest to it: potash, citation, loar, reconstruction, terengganu, farts, annex, smyth,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, trotskyist, duodenum, astronautics,
# Nearest to system: orbited, incredibly, valverde, adb, itch, estudios, embossing, tang,
# Nearest to prince: siddha, schlegel, stubborn, czi, asu, delores, selim, brooklyn,
# Nearest to heavy: ksi, atx, bump, availible, diego, mixed, teborg, robustness,
# Nearest to issue: transitory, popper, exemplar, noam, locative, bpo, sponsorships, condemning,
# Nearest to instance: handy, connery, schedules, garibaldi, subordinate, crystallizes, deckers, usb,
# Nearest to something: reidel, cristae, chloramine, yamaha, ils, monochrome, busway, unmodified,
# Nearest to pre: ob, turismo, subjectively, mannerist, aboriginal, registered, papuan, conceding,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, whitby, enos, nitrites, kirby,
# Nearest to accepted: doctoral, connote, ecole, bubiyan, beringer, luigi, fln, transcaucasian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.4305 0.1963 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.3460 0.1984 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.3153 0.2059 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.3495 0.2007 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.3304 0.2020 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.3794 0.2024 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.3805 0.2040 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.3873 0.2072 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.3780 0.2074 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.4112 0.2025 sec/batch
# Nearest to war: machiavellian, gabaa, flores, rosamund, reserves, revenues, conservancy, shikoku,
# Nearest to years: nahash, november, financially, welling, covert, crete, vah, kochi,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, augmentation, scorched, scapegoat,
# Nearest to had: russia, cournot, mifune, husayni, blowing, od, jealous, kazantzakis,
# Nearest to were: paratrooper, korah, rediscovery, injustice, clarified, pwn, flo, unrecognizable,
# Nearest to it: potash, citation, loar, reconstruction, terengganu, farts, goitre, annex,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, trotskyist, straightforwardly, duodenum,
# Nearest to system: orbited, incredibly, valverde, itch, embossing, adb, hagerstown, mahwah,
# Nearest to prince: siddha, schlegel, asu, stubborn, czi, delores, selim, brooklyn,
# Nearest to heavy: ksi, atx, bump, availible, diego, teborg, mixed, robustness,
# Nearest to issue: transitory, popper, encode, locative, noam, sponsorships, exemplar, bpo,
# Nearest to instance: handy, schedules, connery, deckers, garibaldi, subordinate, crystallizes, usb,
# Nearest to something: reidel, cristae, chloramine, yamaha, ils, unmodified, busway, midway,
# Nearest to pre: ob, turismo, subjectively, aboriginal, mannerist, papuan, registered, elevators,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, enos, specialty, kirby, whitby,
# Nearest to accepted: connote, doctoral, ecole, fln, bubiyan, disorder, luigi, scientific,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.3244 0.2066 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.3638 0.2080 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.3702 0.2061 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.3794 0.2086 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.4336 0.2043 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.3921 0.2051 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.3258 0.1953 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.4072 0.1938 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.3689 0.1940 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.3435 0.1946 sec/batch
# Nearest to war: machiavellian, gabaa, flores, rosamund, reserves, revenues, shikoku, conservancy,
# Nearest to years: nahash, november, financially, welling, crete, covert, vah, kochi,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, scorched, augmentation, scapegoat,
# Nearest to had: russia, cournot, mifune, od, husayni, integrate, jealous, hsieh,
# Nearest to were: paratrooper, korah, rediscovery, injustice, clarified, pwn, flo, unrecognizable,
# Nearest to it: potash, citation, loar, reconstruction, terengganu, smyth, annex, farts,
# Nearest to be: disaffection, peer, monteagle, trotskyist, intensified, wobbly, straightforwardly, cytokines,
# Nearest to system: orbited, valverde, incredibly, itch, adb, embossing, mahwah, hagerstown,
# Nearest to prince: siddha, stubborn, czi, schlegel, asu, selim, delores, marva,
# Nearest to heavy: atx, bump, ksi, availible, diego, teborg, mixed, robustness,
# Nearest to issue: transitory, popper, exemplar, locative, noam, encode, condemning, sponsorships,
# Nearest to instance: handy, garibaldi, schedules, connery, subordinate, deckers, crystallizes, timekeeping,
# Nearest to something: reidel, cristae, chloramine, ils, yamaha, unmodified, busway, monochrome,
# Nearest to pre: turismo, ob, subjectively, aboriginal, mannerist, registered, bid, papuan,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, enos, ignacy, kirby, specialty,
# Nearest to accepted: connote, doctoral, ecole, transcaucasian, scientific, fln, luigi, bubiyan,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.3792 0.1961 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.3866 0.1945 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.2938 0.1933 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.3190 0.1927 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.3849 0.1969 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.3692 0.1973 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.4410 0.1954 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.4693 0.1940 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.3631 0.1937 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.3508 0.1928 sec/batch
# Nearest to war: machiavellian, gabaa, flores, reserves, shikoku, rosamund, kanton, revenues,
# Nearest to years: nahash, november, financially, welling, crete, vah, covert, barf,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, scorched, gendai, augmentation,
# Nearest to had: russia, cournot, mifune, od, husayni, integrate, jealous, kazantzakis,
# Nearest to were: paratrooper, korah, injustice, rediscovery, clarified, pwn, flo, unrecognizable,
# Nearest to it: potash, citation, loar, reconstruction, annex, smyth, terengganu, farts,
# Nearest to be: disaffection, peer, monteagle, intensified, wobbly, trotskyist, straightforwardly, duodenum,
# Nearest to system: orbited, itch, valverde, incredibly, adb, embossing, mahwah, hagerstown,
# Nearest to prince: siddha, stubborn, schlegel, czi, asu, selim, delores, marva,
# Nearest to heavy: atx, bump, ksi, availible, diego, teborg, mixed, robustness,
# Nearest to issue: transitory, popper, exemplar, locative, encode, noam, sponsorships, bpo,
# Nearest to instance: handy, schedules, subordinate, connery, timekeeping, crystallizes, deckers, garibaldi,
# Nearest to something: reidel, cristae, chloramine, midway, yamaha, busway, ils, unmodified,
# Nearest to pre: ob, turismo, subjectively, aboriginal, mannerist, registered, conceding, rrs,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, kirby, enos, specialty, awakened,
# Nearest to accepted: connote, ecole, doctoral, transcaucasian, scientific, luigi, bubiyan, fln,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.3664 0.1958 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.2470 0.1929 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.4041 0.1951 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.3257 0.1937 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.3514 0.1958 sec/batch
# Epoch 5/10 Iteration: 17600 Avg. Training loss: 3.3725 0.0699 sec/batch
# Epoch 5/10 Iteration: 17700 Avg. Training loss: 3.2803 0.1938 sec/batch
# Epoch 5/10 Iteration: 17800 Avg. Training loss: 3.2979 0.2014 sec/batch
# Epoch 5/10 Iteration: 17900 Avg. Training loss: 3.3261 0.2066 sec/batch
# Epoch 5/10 Iteration: 18000 Avg. Training loss: 3.2882 0.2025 sec/batch
# Nearest to war: gabaa, machiavellian, flores, shikoku, rosamund, reserves, kanton, conservancy,
# Nearest to years: nahash, november, financially, welling, crete, vah, covert, imploded,
# Nearest to four: throttled, civilised, condominiums, watershed, roared, scorched, augmentation, gendai,
# Nearest to had: russia, cournot, mifune, husayni, od, integrate, mcc, harker,
# Nearest to were: paratrooper, korah, injustice, rediscovery, clarified, pwn, flo, unrecognizable,
# Nearest to it: potash, citation, loar, reconstruction, terengganu, smyth, annex, farts,
# Nearest to be: disaffection, peer, monteagle, trotskyist, straightforwardly, wobbly, intensified, transparent,
# Nearest to system: orbited, valverde, itch, hagerstown, embossing, incredibly, adb, mahwah,
# Nearest to prince: siddha, schlegel, stubborn, czi, delores, selim, asu, marva,
# Nearest to heavy: atx, ksi, bump, availible, diego, teborg, mixed, robustness,
# Nearest to issue: transitory, locative, popper, exemplar, encode, noam, sponsorships, florin,
# Nearest to instance: handy, schedules, connery, garibaldi, crystallizes, deckers, subordinate, timekeeping,
# Nearest to something: reidel, cristae, midway, chloramine, yamaha, busway, unmodified, ils,
# Nearest to pre: ob, subjectively, turismo, aboriginal, mannerist, registered, bid, nevertheless,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, enos, specialty, kirby, decisively,
# Nearest to accepted: connote, scientific, doctoral, ecole, transcaucasian, luigi, fln, disorder,
# Epoch 5/10 Iteration: 18100 Avg. Training loss: 3.3241 0.2122 sec/batch
# Epoch 5/10 Iteration: 18200 Avg. Training loss: 3.2697 0.2039 sec/batch
# Epoch 5/10 Iteration: 18300 Avg. Training loss: 3.3380 0.2021 sec/batch
# Epoch 5/10 Iteration: 18400 Avg. Training loss: 3.3037 0.2029 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 3.3795 0.2055 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.2816 0.1993 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.2077 0.2068 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.2553 0.2046 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.2837 0.2025 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.3534 0.1993 sec/batch
# Nearest to war: machiavellian, gabaa, flores, shikoku, rosamund, reserves, revenues, conservancy,
# Nearest to years: nahash, november, financially, welling, covert, crete, vah, vendors,
# Nearest to four: throttled, civilised, watershed, roared, condominiums, scorched, gendai, augmentation,
# Nearest to had: russia, cournot, mifune, husayni, od, integrate, mcc, harker,
# Nearest to were: paratrooper, korah, rediscovery, injustice, clarified, pwn, flo, theories,
# Nearest to it: potash, loar, citation, reconstruction, terengganu, smyth, annex, farts,
# Nearest to be: disaffection, peer, trotskyist, straightforwardly, monteagle, wobbly, tiered, intensified,
# Nearest to system: orbited, itch, embossing, valverde, hagerstown, adb, incredibly, mahwah,
# Nearest to prince: siddha, stubborn, delores, schlegel, czi, asu, marva, selim,
# Nearest to heavy: atx, ksi, bump, availible, teborg, diego, creative, robustness,
# Nearest to issue: transitory, exemplar, encode, popper, locative, bpo, resistant, extinctions,
# Nearest to instance: handy, schedules, connery, subordinate, garibaldi, crystallizes, timekeeping, diasporas,
# Nearest to something: reidel, cristae, midway, yamaha, busway, unmodified, chloramine, arranger,
# Nearest to pre: ob, subjectively, turismo, aboriginal, hawley, registered, salads, mannerist,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, specialty, enos, decisively, kirby,
# Nearest to accepted: connote, scientific, doctoral, ecole, fln, beringer, transcaucasian, shahada,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.3013 0.1963 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.3149 0.1932 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.3071 0.1932 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.3669 0.1951 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.2240 0.1946 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.2888 0.1938 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.3391 0.1941 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.2795 0.1944 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.3522 0.1952 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.3578 0.1937 sec/batch
# Nearest to war: gabaa, machiavellian, flores, shikoku, reserves, rosamund, revenues, kanton,
# Nearest to years: nahash, november, financially, welling, covert, crete, vah, barf,
# Nearest to four: throttled, civilised, watershed, condominiums, roared, scorched, gendai, scapegoat,
# Nearest to had: cournot, russia, mifune, husayni, mcc, phenyl, od, jealous,
# Nearest to were: paratrooper, rediscovery, korah, injustice, pwn, clarified, flo, theories,
# Nearest to it: potash, loar, citation, reconstruction, terengganu, farts, smyth, annex,
# Nearest to be: disaffection, trotskyist, peer, straightforwardly, monteagle, intensified, wobbly, tiered,
# Nearest to system: itch, orbited, hagerstown, adb, valverde, incredibly, embossing, mahwah,
# Nearest to prince: siddha, czi, delores, selim, stubborn, asu, schlegel, marva,
# Nearest to heavy: atx, bump, ksi, availible, diego, teborg, creative, robustness,
# Nearest to issue: transitory, popper, encode, exemplar, locative, lantern, noam, extinctions,
# Nearest to instance: handy, schedules, timekeeping, connery, crystallizes, garibaldi, deckers, subordinate,
# Nearest to something: reidel, cristae, midway, busway, unmodified, yamaha, arranger, chloramine,
# Nearest to pre: ob, subjectively, turismo, aboriginal, hawley, laker, registered, fano,
# Nearest to construction: rosenbaum, chondrite, congresswoman, remarried, enos, specialty, subdominant, awakened,
# Nearest to accepted: connote, doctoral, shahada, agreed, scientific, ecole, electors, transcaucasian,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.2581 0.1957 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.3366 0.1942 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.3231 0.1932 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.2929 0.2014 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.3328 0.2031 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.3034 0.2044 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.2503 0.2049 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.2844 0.1988 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.3690 0.2079 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.3402 0.2078 sec/batch
# Nearest to war: gabaa, machiavellian, flores, shikoku, reserves, rosamund, revenues, kanton,
# Nearest to years: nahash, november, financially, welling, covert, crete, vah, barf,
# Nearest to four: throttled, civilised, roared, watershed, condominiums, scorched, augmentation, gendai,
# Nearest to had: cournot, russia, mifune, husayni, phenyl, integrate, mcc, od,
# Nearest to were: paratrooper, rediscovery, korah, injustice, pwn, clarified, flo, demilitarization,
# Nearest to it: potash, loar, citation, reconstruction, terengganu, farts, smyth, goitre,
# Nearest to be: disaffection, trotskyist, peer, straightforwardly, wobbly, tiered, salts, monteagle,
# Nearest to system: itch, orbited, adb, hagerstown, valverde, embossing, mahwah, lawson,
# Nearest to prince: siddha, czi, selim, delores, stubborn, asu, schlegel, marva,
# Nearest to heavy: atx, bump, availible, ksi, diego, teborg, creative, robustness,
# Nearest to issue: transitory, popper, exemplar, locative, encode, extinctions, lantern, noam,
# Nearest to instance: handy, schedules, connery, subordinate, timekeeping, garibaldi, deckers, incubator,
# Nearest to something: reidel, cristae, midway, busway, arranger, unmodified, chloramine, sceptre,
# Nearest to pre: ob, subjectively, turismo, aboriginal, bid, hawley, fano, salads,
# Nearest to construction: rosenbaum, chondrite, remarried, congresswoman, enos, specialty, awakened, subdominant,
# Nearest to accepted: connote, shahada, scientific, ecole, transcaucasian, doctoral, agreed, electors,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.3801 0.2084 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.3930 0.2021 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.2553 0.1959 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.2732 0.1928 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.2965 0.1924 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.1347 0.1932 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.3537 0.1950 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.2911 0.2028 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.2858 0.2023 sec/batch
# Epoch 6/10 Iteration: 22000 Avg. Training loss: 3.3577 0.0871 sec/batch
# Nearest to war: gabaa, machiavellian, flores, shikoku, rosamund, revenues, reserves, gelre,
# Nearest to years: nahash, november, financially, welling, crete, covert, vah, barf,
# Nearest to four: throttled, civilised, watershed, roared, condominiums, scorched, augmentation, gendai,
# Nearest to had: cournot, russia, mifune, phenyl, husayni, integrate, mcc, od,
# Nearest to were: paratrooper, korah, rediscovery, injustice, pwn, clarified, flo, theories,
# Nearest to it: potash, loar, citation, reconstruction, terengganu, smyth, farts, goitre,
# Nearest to be: disaffection, trotskyist, peer, straightforwardly, wobbly, tiered, monteagle, transparent,
# Nearest to system: itch, hagerstown, adb, orbited, valverde, embossing, estudios, mahwah,
# ...
# Epoch 9/10 Iteration: 36300 Avg. Training loss: 3.0988 0.2059 sec/batch
# Epoch 9/10 Iteration: 36400 Avg. Training loss: 3.1394 0.2009 sec/batch
# Epoch 9/10 Iteration: 36500 Avg. Training loss: 3.1161 0.1943 sec/batch
# Epoch 9/10 Iteration: 36600 Avg. Training loss: 3.1812 0.1920 sec/batch
# Epoch 9/10 Iteration: 36700 Avg. Training loss: 3.1364 0.1924 sec/batch
# Epoch 9/10 Iteration: 36800 Avg. Training loss: 3.1474 0.1937 sec/batch
# Epoch 9/10 Iteration: 36900 Avg. Training loss: 3.1474 0.1927 sec/batch
# Epoch 9/10 Iteration: 37000 Avg. Training loss: 3.2413 0.1940 sec/batch
# Nearest to war: flores, gabaa, machiavellian, shikoku, rosamund, stranglers, reserves, kanton,
# Nearest to years: nahash, november, adds, barf, ambiguously, crete, welling, tolbert,
# Nearest to four: throttled, roared, civilised, watershed, manifestos, willy, gendai, scapegoat,
# Nearest to had: russia, mcc, cournot, husayni, mifune, phenyl, accolades, integrate,
# Nearest to were: pwn, paratrooper, flo, rediscovery, injustice, korah, theories, destabilization,
# Nearest to it: potash, loar, reconstruction, citation, adjoined, terengganu, smyth, biologist,
# Nearest to be: straightforwardly, transparent, disaffection, tiered, trotskyist, salts, monteagle, neighborhoods,
# Nearest to system: seiy, hagerstown, lawson, embossing, itch, adb, fretting, delavan,
# Nearest to prince: siddha, castle, mulk, delores, stubborn, mommu, concerto, czi,
# Nearest to heavy: atx, creative, ksi, availible, bump, decennial, curves, diego,
# Nearest to issue: lantern, circulate, tougher, extinctions, popper, awesome, locative, books,
# Nearest to instance: handy, rockers, thus, incubator, sqrtn, pharyngealized, schedules, exception,
# Nearest to something: reidel, cristae, midway, arranger, kiwifruit, former, busway, ballantine,
# Nearest to pre: subjectively, ob, filings, salads, aboriginal, bid, turismo, elevators,
# Nearest to construction: rosenbaum, chondrite, furtado, lossy, remarried, congresswoman, buckskin, nitrites,
# Nearest to accepted: connote, agreed, concluded, scientific, shahada, rigorously, talib, reserving,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.0977 0.1961 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.1656 0.1943 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.1822 0.1929 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.1802 0.1928 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.1799 0.1925 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.1509 0.1939 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.1474 0.1932 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.1775 0.1944 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.1741 0.1946 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.1771 0.1962 sec/batch
# Nearest to war: flores, gabaa, machiavellian, shikoku, rosamund, stranglers, reserves, kanton,
# Nearest to years: nahash, november, crete, asis, welling, barf, adds, tolbert,
# Nearest to four: throttled, roared, watershed, civilised, willy, manifestos, gendai, scapegoat,
# Nearest to had: russia, cournot, mcc, husayni, mifune, integrate, qf, phenyl,
# Nearest to were: pwn, paratrooper, flo, rediscovery, korah, injustice, theories, invader,
# Nearest to it: potash, loar, reconstruction, citation, adjoined, smyth, bakkers, terengganu,
# Nearest to be: straightforwardly, disaffection, transparent, tiered, trotskyist, salts, neighborhoods, monteagle,
# Nearest to system: seiy, hagerstown, embossing, itch, lawson, adb, bef, fretting,
# Nearest to prince: siddha, mommu, mulk, ascended, castle, czi, delores, selim,
# Nearest to heavy: atx, creative, availible, ksi, bump, decennial, slimy, diego,
# Nearest to issue: lantern, circulate, popper, tougher, extinctions, locative, encode, invalidated,
# Nearest to instance: rockers, handy, thus, exception, incubator, garibaldi, sqrtn, subordinate,
# Nearest to something: reidel, cristae, arranger, kiwifruit, midway, sceptre, busway, juliana,
# Nearest to pre: subjectively, ob, bid, filings, salads, turismo, aboriginal, nanette,
# Nearest to construction: rosenbaum, chondrite, lossy, furtado, remarried, enos, congresswoman, awakened,
# Nearest to accepted: agreed, concluded, shahada, rigorously, connote, scientific, talib, reserving,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.1629 0.1987 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.0989 0.1954 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.1274 0.2046 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.1613 0.2015 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.1650 0.2104 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.2860 0.2033 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.2235 0.2015 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.2324 0.2023 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.0899 0.2024 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.1135 0.2008 sec/batch
# Nearest to war: flores, gabaa, shikoku, machiavellian, rosamund, stranglers, reserves, kanton,
# Nearest to years: nahash, november, crete, asis, adds, barf, mitzvot, ambiguously,
# Nearest to four: throttled, roared, watershed, willy, civilised, scapegoat, scorched, manifestos,
# Nearest to had: russia, cournot, mcc, integrate, qf, husayni, accolades, mifune,
# Nearest to were: pwn, paratrooper, flo, theories, korah, rediscovery, invader, injustice,
# Nearest to it: potash, loar, reconstruction, citation, adjoined, biologist, terengganu, smyth,
# Nearest to be: straightforwardly, disaffection, transparent, tiered, trotskyist, salts, monteagle, neighborhoods,
# Nearest to system: seiy, itch, hagerstown, lawson, embossing, adb, fretting, bef,
# Nearest to prince: siddha, mulk, mommu, delores, czi, castle, ascended, selim,
# Nearest to heavy: creative, atx, availible, bump, ksi, decennial, metropolises, slimy,
# Nearest to issue: lantern, popper, circulate, locative, decided, invalidated, september, exemplar,
# Nearest to instance: thus, rockers, can, handy, sqrtn, incubator, multidimensional, several,
# Nearest to something: reidel, cristae, midway, kiwifruit, busway, arranger, former, ballantine,
# Nearest to pre: subjectively, ob, bid, salads, turismo, filings, aboriginal, nanette,
# Nearest to construction: rosenbaum, chondrite, congresswoman, furtado, remarried, lossy, martyn, enos,
# Nearest to accepted: agreed, concluded, rigorously, scientific, connote, shahada, reserving, alphonsus,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.1794 0.2101 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.0495 0.2002 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.1960 0.2063 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.1473 0.1994 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.2303 0.2019 sec/batch
# Epoch 10/10 Iteration: 39600 Avg. Training loss: 3.1418 0.1571 sec/batch
# Epoch 10/10 Iteration: 39700 Avg. Training loss: 3.1340 0.1942 sec/batch
# Epoch 10/10 Iteration: 39800 Avg. Training loss: 3.1435 0.1973 sec/batch
# Epoch 10/10 Iteration: 39900 Avg. Training loss: 3.1479 0.1936 sec/batch
# Epoch 10/10 Iteration: 40000 Avg. Training loss: 3.1491 0.1934 sec/batch
# Nearest to war: flores, gabaa, machiavellian, shikoku, rosamund, stranglers, reserves, kanton,
# Nearest to years: nahash, november, adds, asis, rats, crete, mitzvot, barf,
# Nearest to four: throttled, roared, watershed, willy, civilised, scapegoat, manifestos, scorched,
# Nearest to had: russia, cournot, mcc, integrate, qf, accolades, husayni, mifune,
# Nearest to were: pwn, paratrooper, flo, theories, rediscovery, korah, invader, demilitarization,
# Nearest to it: potash, reconstruction, loar, adjoined, citation, biologist, smyth, terengganu,
# Nearest to be: straightforwardly, transparent, tiered, disaffection, trotskyist, salts, neighborhoods, monteagle,
# Nearest to system: seiy, itch, lawson, hagerstown, embossing, adb, estudios, fretting,
# Nearest to prince: siddha, mulk, czi, mommu, delores, castle, selim, ascended,
# Nearest to heavy: creative, atx, availible, ksi, bump, decennial, metropolises, slimy,
# Nearest to issue: lantern, circulate, popper, locative, spacetimes, extinctions, invalidated, tougher,
# Nearest to instance: rockers, thus, several, exception, garibaldi, sabbat, pharyngealized, handy,
# Nearest to something: cristae, reidel, former, midway, arranger, kiwifruit, busway, extends,
# Nearest to pre: subjectively, ob, turismo, filings, bid, aboriginal, salads, elevators,
# Nearest to construction: rosenbaum, enos, chondrite, furtado, congresswoman, lossy, martyn, awakened,
# Nearest to accepted: connote, concluded, agreed, shahada, rigorously, talib, scientific, beringer,
# Epoch 10/10 Iteration: 40100 Avg. Training loss: 3.1462 0.2086 sec/batch
# Epoch 10/10 Iteration: 40200 Avg. Training loss: 3.0941 0.1936 sec/batch
# Epoch 10/10 Iteration: 40300 Avg. Training loss: 3.0888 0.1915 sec/batch
# Epoch 10/10 Iteration: 40400 Avg. Training loss: 3.1337 0.1940 sec/batch
# Epoch 10/10 Iteration: 40500 Avg. Training loss: 3.1836 0.1922 sec/batch
# Epoch 10/10 Iteration: 40600 Avg. Training loss: 3.0610 0.1930 sec/batch
# Epoch 10/10 Iteration: 40700 Avg. Training loss: 3.1191 0.1920 sec/batch
# Epoch 10/10 Iteration: 40800 Avg. Training loss: 3.1474 0.1933 sec/batch
# Epoch 10/10 Iteration: 40900 Avg. Training loss: 3.0998 0.1913 sec/batch
# Epoch 10/10 Iteration: 41000 Avg. Training loss: 3.1782 0.1930 sec/batch
# Nearest to war: gabaa, machiavellian, flores, shikoku, stranglers, rosamund, tolerant, kanton,
# Nearest to years: nahash, november, adds, asis, mitzvot, crete, barf, welling,
# Nearest to four: throttled, watershed, roared, willy, civilised, manifestos, scapegoat, scorched,
# Nearest to had: russia, cournot, mcc, integrate, qf, husayni, mifune, phenyl,
# Nearest to were: paratrooper, pwn, flo, rediscovery, theories, korah, injustice, demilitarization,
# Nearest to it: potash, reconstruction, loar, adjoined, citation, biologist, smyth, terengganu,
# Nearest to be: transparent, straightforwardly, tiered, disaffection, trotskyist, salts, monteagle, wobbly,
# Nearest to system: seiy, embossing, itch, hagerstown, estudios, lawson, adb, incredibly,
# Nearest to prince: siddha, delores, mulk, castle, ascended, stubborn, marva, mommu,
# Nearest to heavy: creative, atx, availible, ksi, bump, decennial, curves, metropolises,
# Nearest to issue: circulate, lantern, popper, invalidated, tougher, spacetimes, locative, extinctions,
# Nearest to instance: thus, rockers, several, incubator, can, exception, sqrtn, garibaldi,
# Nearest to something: cristae, reidel, midway, kiwifruit, arranger, former, busway, extends,
# Nearest to pre: subjectively, ob, filings, aboriginal, salads, turismo, elevators, meadows,
# Nearest to construction: rosenbaum, enos, chondrite, furtado, congresswoman, lossy, remarried, martyn,
# Nearest to accepted: agreed, shahada, connote, concluded, accept, rigorously, scientific, taught,
# Epoch 10/10 Iteration: 41100 Avg. Training loss: 3.1554 0.1970 sec/batch
# Epoch 10/10 Iteration: 41200 Avg. Training loss: 3.1281 0.1925 sec/batch
# Epoch 10/10 Iteration: 41300 Avg. Training loss: 3.1564 0.1995 sec/batch
# Epoch 10/10 Iteration: 41400 Avg. Training loss: 3.2130 0.2032 sec/batch
# Epoch 10/10 Iteration: 41500 Avg. Training loss: 3.0757 0.2017 sec/batch
# Epoch 10/10 Iteration: 41600 Avg. Training loss: 3.1549 0.2029 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.1061 0.2006 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.1413 0.2036 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.1733 0.2010 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.1515 0.1941 sec/batch
# Nearest to war: gabaa, flores, machiavellian, shikoku, tolerant, rosamund, stranglers, retort,
# Nearest to years: nahash, november, adds, asis, barf, ambiguously, nagaoka, crete,
# Nearest to four: throttled, watershed, roared, willy, manifestos, scapegoat, civilised, mononobe,
# Nearest to had: russia, cournot, mcc, integrate, qf, mifune, accolades, husayni,
# Nearest to were: paratrooper, pwn, flo, rediscovery, theories, korah, destabilization, demilitarization,
# Nearest to it: potash, reconstruction, loar, adjoined, citation, biologist, shaikh, utilize,
# Nearest to be: transparent, straightforwardly, disaffection, tiered, trotskyist, salts, monteagle, wobbly,
# Nearest to system: seiy, embossing, hagerstown, itch, ree, lawson, incredibly, adb,
# Nearest to prince: siddha, ascended, mommu, mulk, czi, delores, castle, selim,
# Nearest to heavy: creative, atx, availible, ksi, bump, decennial, slimy, tranquil,
# Nearest to issue: lantern, circulate, popper, invalidated, tougher, spacetimes, extinctions, locative,
# Nearest to instance: rockers, thus, several, exception, incubator, sqrtn, sabbat, handy,
# Nearest to something: reidel, cristae, midway, kiwifruit, extends, arranger, busway, svoboda,
# Nearest to pre: subjectively, ob, filings, turismo, elevators, salads, aboriginal, meadows,
# Nearest to construction: rosenbaum, chondrite, enos, furtado, lossy, congresswoman, martyn, buckskin,
# Nearest to accepted: agreed, concluded, connote, shahada, rigorously, taught, accept, scientific,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.1075 0.1952 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.1422 0.1929 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.1343 0.1947 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.1294 0.1944 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.1316 0.1929 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.0889 0.1952 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.0972 0.1923 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.1544 0.1938 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.1302 0.1971 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.2645 0.1961 sec/batch
# Nearest to war: gabaa, shikoku, machiavellian, flores, tolerant, stranglers, retort, kanton,
# Nearest to years: nahash, november, adds, asis, barf, ambiguously, crete, disgusting,
# Nearest to four: throttled, willy, roared, watershed, scapegoat, civilised, mononobe, manifestos,
# Nearest to had: russia, cournot, mcc, integrate, qf, mifune, accolades, husayni,
# Nearest to were: pwn, paratrooper, flo, rediscovery, theories, korah, demilitarization, invader,
# Nearest to it: potash, reconstruction, adjoined, loar, citation, shaikh, biologist, utilize,
# Nearest to be: transparent, straightforwardly, disaffection, tiered, trotskyist, salts, neighborhoods, monteagle,
# Nearest to system: seiy, embossing, hagerstown, itch, adb, bef, lawson, ree,
# Nearest to prince: siddha, mulk, ascended, mommu, czi, delores, selim, castle,
# Nearest to heavy: creative, atx, availible, ksi, decennial, bump, metropolises, tranquil,
# Nearest to issue: lantern, circulate, popper, invalidated, tougher, spacetimes, parkinson, extinctions,
# Nearest to instance: rockers, thus, incubator, sabbat, exception, several, sqrtn, riebeeck,
# Nearest to something: cristae, reidel, midway, kiwifruit, busway, extends, arranger, sceptre,
# Nearest to pre: subjectively, ob, meadows, filings, salads, turismo, bid, aboriginal,
# Nearest to construction: rosenbaum, chondrite, lossy, furtado, enos, martyn, congresswoman, buckskin,
# Nearest to accepted: agreed, concluded, rigorously, accept, shahada, majed, connote, roshan,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.1725 0.1957 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.2255 0.1941 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.0771 0.1932 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.1124 0.1903 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.1193 0.1935 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.0391 0.1947 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.1408 0.1938 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.1077 0.1946 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.2066 0.1942 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# <font color="red">**NOTE**</font>
# The following might fail with `ValueError: array must not contain infs or NaNs`. See this [Github issue](https://github.com/scikit-learn/scikit-learn/issues/6665). The following code snippet can be used for testing:
# ```
# import numpy as np
# import random
# from sklearn.manifold import TSNE
# random.seed(1)
# a = np.random.uniform(size=(100,20))
# TSNE(n_components=2).fit_transform(a)
# ```
#
# <font color="purple">**UPDATE**</font>
# Upgrading to `numpy 1.13.1`, `scipy 0.19.1`, and `scikit-learn 0.19.0` seemed to fix the problem.

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# **Note:** Looks considerably worse than the one in the [solution](http://localhost:8888/notebooks/Skip-Grams-Solution.ipynb).
