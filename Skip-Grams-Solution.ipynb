# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6880 0.1930 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6090 0.2073 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5018 0.2185 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6050 0.2116 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5155 0.2037 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4944 0.2027 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5720 0.2032 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5428 0.2019 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4705 0.2019 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4235 0.2036 sec/batch
# Nearest to that: estate, peasant, inferior, yogurt, halted, writing, alphabetically, juices,
# Nearest to more: michinaga, islami, religious, striker, virus, legionnaire, positioning, beatty,
# Nearest to th: moyen, expositor, deorum, bani, athenian, constellation, finns, vpn,
# Nearest to while: hallows, blasted, antiope, polyn, wresting, fleury, dogfights, brethren,
# Nearest to with: misfit, prized, snowfall, nils, ccj, hbf, irreconcilable, petitioning,
# Nearest to united: lichtenberg, clarion, nessie, sell, aquitaine, oost, cumming, grenville,
# Nearest to zero: kathmandu, saved, gluons, economical, divas, herzog, orren, defend,
# Nearest to for: sprinkling, navel, forearm, rence, philologie, reinforced, oboes, ton,
# Nearest to versions: rotuma, mcgann, fetuses, number, hour, hobbyist, irrealism, embossed,
# Nearest to something: mishearing, stove, eliyahu, knitted, renderman, handedly, bettina, dependability,
# Nearest to existence: landfall, unchecked, crumbled, eminently, speciation, investigative, ama, bhfuil,
# Nearest to animals: shapeshifting, hints, fang, syzygy, persecutor, shared, pederasty, sacking,
# Nearest to freedom: externally, bally, adrenal, cafiero, aikijutsu, empowering, clr, caricature,
# Nearest to event: dimitri, mild, dari, stromata, fur, cosmetic, irrefutable, iupac,
# Nearest to construction: ringgit, anaxagoras, goodrich, secrete, dirkjan, newscaster, vegetarians, whiskers,
# Nearest to pressure: zainab, cdm, furlongs, full, nomadic, lda, archbishops, headquarters,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4866 0.2057 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3492 0.2046 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3353 0.2036 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2679 0.2030 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1614 0.2062 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1372 0.2029 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0778 0.2056 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0522 0.2031 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0088 0.2062 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9716 0.2040 sec/batch
# Nearest to that: estate, writing, inferior, major, peasant, constructing, published, encompasses,
# Nearest to more: religious, striker, islami, completes, positioning, virus, michinaga, anatomy,
# Nearest to th: moyen, expositor, athenian, among, constellation, finns, madness, smithsonian,
# Nearest to while: blasted, hallows, manifesto, sessions, dissimilar, brethren, widths, looking,
# Nearest to with: snowfall, misfit, prized, eerily, irreconcilable, nils, delaware, did,
# Nearest to united: sell, clarion, aquitaine, lichtenberg, divergence, extent, oost, positioned,
# Nearest to zero: saved, kathmandu, defend, gilbert, norway, economical, cal, gluons,
# Nearest to for: scholars, sprinkling, navel, eisenhower, reinforced, scoring, realms, ton,
# Nearest to versions: mcgann, rotuma, hour, number, fetuses, launched, far, closed,
# Nearest to something: mishearing, simmonds, knitted, intercept, eliyahu, stove, orange, placed,
# Nearest to existence: landfall, scene, math, eigenvalues, somewhere, derek, gallon, ama,
# Nearest to animals: shapeshifting, hints, shared, fang, millennium, touched, malaysia, syzygy,
# Nearest to freedom: externally, amount, bally, adrenal, traumatic, designs, clr, caricature,
# Nearest to event: mild, dimitri, cosmetic, stromata, less, fur, commentary, dari,
# Nearest to construction: dirkjan, except, whiskers, newscaster, anaxagoras, langmuir, politics, vegetarians,
# Nearest to pressure: full, headquarters, temperate, cdm, glycolysis, argue, enterprises, avoiding,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9218 0.2081 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9073 0.2038 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8873 0.2065 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8668 0.2006 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8130 0.2023 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7966 0.2047 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7868 0.2084 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7962 0.2178 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8008 0.2101 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7732 0.2127 sec/batch
# Nearest to that: estate, writing, answers, fractures, inferior, constructing, girlfriend, savanna,
# Nearest to more: religious, virus, michinaga, positioning, striker, islami, proliferation, anatomy,
# Nearest to th: moyen, expositor, constellation, finns, madness, smithsonian, suez, athenian,
# Nearest to while: blasted, brethren, manifesto, sessions, hallows, dissimilar, adamant, widths,
# Nearest to with: misfit, snowfall, prized, nils, orbit, dependencies, defender, skirmish,
# Nearest to united: aquitaine, clarion, sell, positioned, lichtenberg, contaminating, grenville, veto,
# Nearest to zero: norway, gilbert, four, york, commodities, saved, gluons, bainimarama,
# Nearest to for: scholars, reinforced, sprinkling, navel, scoring, eisenhower, liberal, duplicated,
# Nearest to versions: mcgann, rotuma, hour, number, launched, hobbyist, elisabeth, fetuses,
# Nearest to something: mishearing, stove, fascist, knitted, simmonds, paintings, eliyahu, intercept,
# Nearest to existence: landfall, somewhere, math, gallon, energy, scene, eigenvalues, crumbled,
# Nearest to animals: shapeshifting, hints, shared, fang, millennium, malaysia, touched, visitors,
# Nearest to freedom: externally, amount, irrespective, traumatic, bally, designs, adrenal, dog,
# Nearest to event: dimitri, mild, stromata, cosmetic, less, commentary, dari, fur,
# Nearest to construction: dirkjan, politics, newscaster, anaxagoras, except, visiting, whiskers, phd,
# Nearest to pressure: headquarters, temperate, full, nomadic, amplification, cdm, avoiding, glycolysis,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7800 0.2143 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7598 0.2108 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7356 0.2130 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7230 0.2006 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7194 0.2014 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7230 0.1990 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7161 0.1973 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7327 0.1978 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6911 0.1975 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6770 0.1984 sec/batch
# Nearest to that: estate, fractures, answers, writing, inferior, constructing, gardnerian, savanna,
# Nearest to more: religious, michinaga, virus, proliferation, anatomy, islami, striker, positioning,
# Nearest to th: moyen, expositor, finns, smithsonian, suez, constellation, madness, deorum,
# Nearest to while: blasted, hallows, sessions, widths, adamant, brethren, dissimilar, khwarizmi,
# Nearest to with: misfit, snowfall, skirmish, dependencies, prized, defender, licences, orbit,
# Nearest to united: aquitaine, sell, clarion, veto, blackstone, eisenach, grenville, filmography,
# Nearest to zero: four, two, norway, york, est, gilbert, eight, commodities,
# Nearest to for: scholars, eisenhower, navel, sprinkling, awarding, scoring, reinforced, ton,
# Nearest to versions: mcgann, rotuma, embossed, diacritics, hour, harmonics, fetuses, number,
# Nearest to something: paintings, knitted, mishearing, stove, eliyahu, fascist, norbert, simmonds,
# Nearest to existence: landfall, math, somewhere, crumbled, eigenvalues, unchecked, speciation, investigative,
# Nearest to animals: shapeshifting, hints, fang, malaysia, shared, millennium, pederasty, touched,
# Nearest to freedom: externally, bally, amount, unexplained, empowering, irrespective, adrenal, tulip,
# Nearest to event: dimitri, stromata, mild, commentary, syndication, cosmetic, dari, fur,
# Nearest to construction: dirkjan, politics, newscaster, anaxagoras, vegetarians, bargaining, langmuir, secrete,
# Nearest to pressure: temperate, nomadic, cdm, headquarters, amplification, glycolysis, zainab, full,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6743 0.1990 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6620 0.1965 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6255 0.1983 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6356 0.2079 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6258 0.2025 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5951 0.2070 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5765 0.1498 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5463 0.2010 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5237 0.1992 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4836 0.1980 sec/batch
# Nearest to that: answers, fractures, constructing, inferior, writing, contemplation, gardnerian, estate,
# Nearest to more: michinaga, religious, virus, versa, anatomy, ransomed, proliferation, positioning,
# Nearest to th: moyen, expositor, smithsonian, finns, brigitte, suez, deorum, constellation,
# Nearest to while: blasted, sessions, widths, adamant, khwarizmi, cottage, demesne, hallows,
# Nearest to with: misfit, snowfall, skirmish, melton, prized, orbit, delaware, dependencies,
# Nearest to united: aquitaine, eisenach, sell, veto, blackstone, clarion, grenville, cecil,
# Nearest to zero: four, two, eight, est, migrant, york, norway, dramatists,
# Nearest to for: eisenhower, navel, sprinkling, awarding, scholars, scoring, spate, reinforced,
# Nearest to versions: mcgann, hobbyist, joked, embossed, closed, smartest, rotuma, processors,
# Nearest to something: paintings, eliyahu, mishearing, knitted, norbert, stove, fascist, handedly,
# Nearest to existence: landfall, unchecked, crumbled, somewhere, alleging, speciation, americano, thinking,
# Nearest to animals: shapeshifting, hints, malaysia, fang, touched, millennium, shared, pederasty,
# Nearest to freedom: bally, externally, empowering, amount, tulip, irrespective, caricature, destry,
# Nearest to event: dimitri, syndication, mild, stromata, commentary, cosmetic, greco, iupac,
# Nearest to construction: dirkjan, newscaster, secrete, anaxagoras, bargaining, vegetarians, politics, langmuir,
# Nearest to pressure: temperate, cdm, furlongs, glycolysis, amplification, nomadic, headquarters, drainage,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4896 0.1995 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5246 0.1977 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4918 0.1972 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4947 0.1963 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4985 0.1964 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4689 0.1957 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4603 0.1968 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3967 0.2024 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4147 0.2028 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4482 0.1978 sec/batch
# Nearest to that: answers, fractures, contemplation, constructing, inferior, gardnerian, writing, bornemisza,
# Nearest to more: michinaga, religious, virus, positioning, anatomy, versa, ransomed, proliferation,
# Nearest to th: expositor, moyen, smithsonian, brigitte, constellation, finns, suez, deorum,
# Nearest to while: blasted, widths, demesne, wresting, cottage, adamant, periods, dissimilar,
# Nearest to with: snowfall, misfit, prized, skirmish, orbit, whitewashing, talent, melton,
# Nearest to united: veto, aquitaine, eisenach, grenville, sell, blackstone, countries, consultations,
# Nearest to zero: four, two, est, eight, dramatists, migrant, norway, million,
# Nearest to for: sprinkling, awarding, scoring, eisenhower, navel, forearm, luthor, scholars,
# Nearest to versions: mcgann, closed, hobbyist, embossed, processors, diacritics, stairway, joked,
# Nearest to something: paintings, knitted, norbert, mishearing, eliyahu, fascist, telomeres, stove,
# Nearest to existence: landfall, thinking, alleging, crumbled, speciation, unchecked, respect, accept,
# Nearest to animals: shapeshifting, hints, touched, millennium, shared, everyday, different, fang,
# Nearest to freedom: bally, externally, empowering, girardeau, tulip, amount, irrespective, destry,
# Nearest to event: dimitri, stromata, syndication, mild, commentary, flyer, greco, corinthians,
# Nearest to construction: secrete, dirkjan, newscaster, accentuate, moire, bargaining, hazel, anaxagoras,
# Nearest to pressure: temperate, glycolysis, cdm, amplification, furlongs, materials, caatinga, nomadic,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4522 0.1997 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4339 0.1984 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4514 0.1991 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4191 0.1957 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4237 0.1958 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4340 0.1977 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3882 0.1946 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3861 0.1948 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4304 0.1964 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3744 0.1979 sec/batch
# Nearest to that: answers, fractures, contemplation, gardnerian, constructing, inferior, benzedrine, writing,
# Nearest to more: michinaga, religious, positioning, virus, proliferation, zog, completes, accumulate,
# Nearest to th: expositor, moyen, constellation, smithsonian, brigitte, deorum, finns, suez,
# Nearest to while: demesne, widths, wresting, blasted, periods, cottage, khwarizmi, dissimilar,
# Nearest to with: misfit, snowfall, skirmish, melton, dependencies, ccj, prized, defender,
# Nearest to united: veto, grenville, aquitaine, countries, blackstone, sell, eisenach, pledged,
# Nearest to zero: four, two, est, eight, migrant, dramatists, five, stoked,
# Nearest to for: awarding, luthor, sprinkling, navel, scoring, scholars, eisenhower, susceptibility,
# Nearest to versions: closed, mcgann, embossed, compilation, hobbyist, diacritics, processors, stairway,
# Nearest to something: paintings, norbert, knitted, creator, fascist, eliyahu, telomeres, mishearing,
# Nearest to existence: thinking, landfall, alleging, unchecked, speciation, accept, haykal, respect,
# Nearest to animals: shapeshifting, hints, touched, different, sometimes, everyday, millennium, shared,
# Nearest to freedom: bally, empowering, girardeau, externally, tulip, withdrawn, irrespective, amount,
# Nearest to event: dimitri, stromata, syndication, mild, ectopic, flyer, commentary, lba,
# Nearest to construction: secrete, dirkjan, moire, newscaster, zilog, bargaining, hazel, accentuate,
# Nearest to pressure: amplification, temperate, cdm, glycolysis, kw, materials, oxygen, furlongs,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3619 0.2027 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3949 0.2006 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3652 0.2016 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3731 0.2016 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3963 0.2011 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3614 0.2009 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4104 0.1962 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3814 0.2037 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3415 0.1985 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2914 0.1956 sec/batch
# Nearest to that: answers, contemplation, fractures, constructing, subordinates, inferior, divinity, gardnerian,
# Nearest to more: michinaga, religious, completes, virus, positioning, valiant, zog, centimeter,
# Nearest to th: expositor, moyen, kingdoms, constellation, smithsonian, deorum, finns, brigitte,
# Nearest to while: widths, cottage, demesne, wresting, blasted, khwarizmi, hallows, periods,
# Nearest to with: misfit, snowfall, margrethe, ccj, defender, melton, skirmish, nils,
# Nearest to united: veto, sell, blackstone, grenville, amended, eisenach, pledged, consultations,
# Nearest to zero: four, two, eight, five, est, six, migrant, seven,
# Nearest to for: luthor, navel, awarding, compliant, sprinkling, spate, philologie, tabled,
# Nearest to versions: mcgann, processors, embossed, closed, compilation, diacritics, hobbyist, homepage,
# Nearest to something: norbert, paintings, knitted, telomeres, eliyahu, creator, mishearing, renderman,
# Nearest to existence: thinking, landfall, accept, alleging, haykal, eminently, speciation, anticipated,
# Nearest to animals: shapeshifting, hints, everyday, touched, algerians, different, millennium, indus,
# Nearest to freedom: bally, empowering, girardeau, irrespective, withdrawn, tulip, traumatic, externally,
# Nearest to event: dimitri, stromata, syndication, ectopic, flyer, sc, commentary, picturesque,
# Nearest to construction: secrete, dirkjan, moire, bargaining, zilog, newscaster, rationing, accentuate,
# Nearest to pressure: glycolysis, temperate, furlongs, cdm, amplification, wind, renewable, oxygen,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3551 0.2057 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2734 0.2024 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3658 0.1992 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3725 0.1984 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4034 0.2018 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2849 0.2020 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2684 0.1957 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3491 0.2016 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2476 0.2045 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3067 0.2028 sec/batch
# Nearest to that: answers, fractures, contemplation, constructing, reasons, inferior, hinayana, oneself,
# Nearest to more: michinaga, religious, virus, centimeter, positioning, valiant, anatomy, halfdan,
# Nearest to th: expositor, moyen, smithsonian, deorum, kingdoms, constellation, masovia, gregorian,
# Nearest to while: cottage, widths, hallows, wresting, demesne, biomechanical, blasted, khwarizmi,
# Nearest to with: misfit, snowfall, ccj, margrethe, melton, erhard, hutchison, skirmish,
# Nearest to united: grenville, blackstone, veto, sell, amended, consultations, rhodesia, eisenach,
# Nearest to zero: two, four, eight, five, migrant, six, est, seven,
# Nearest to for: awarding, outpaced, luthor, navel, sprinkling, spate, tabled, rence,
# Nearest to versions: mcgann, embossed, processors, homepage, compilation, diacritics, closed, hobbyist,
# Nearest to something: paintings, norbert, knitted, telomeres, religiosity, eliyahu, creator, renderman,
# Nearest to existence: thinking, landfall, eminently, haykal, accept, alleging, bhfuil, anticipated,
# Nearest to animals: shapeshifting, hints, touched, algerians, everyday, indus, pederasty, tectonics,
# Nearest to freedom: bally, empowering, demonstrations, girardeau, withdrawn, irrespective, tulip, adriaan,
# Nearest to event: dimitri, stromata, syndication, sc, flyer, ectopic, commentary, onstage,
# Nearest to construction: secrete, dirkjan, moire, hazel, newscaster, bargaining, rationing, zilog,
# Nearest to pressure: furlongs, glycolysis, cdm, temperate, amplification, wind, gluconeogenesis, oxygen,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3165 0.2042 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2889 0.1988 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3141 0.0899 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2464 0.2037 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2411 0.2013 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1973 0.2007 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2125 0.1990 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2081 0.2015 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2414 0.2013 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1709 0.2048 sec/batch
# Nearest to that: answers, contemplation, subordinates, oneself, inconceivable, inferior, fractures, reasons,
# Nearest to more: michinaga, religious, positioning, halfdan, virus, valiant, completes, lagrand,
# Nearest to th: expositor, moyen, gregorian, kingdoms, masovia, smithsonian, constellation, deorum,
# Nearest to while: cottage, demesne, wresting, widths, biomechanical, farm, khwarizmi, counsellors,
# Nearest to with: snowfall, misfit, ccj, margrethe, hutchison, tour, skirmish, top,
# Nearest to united: grenville, consultations, veto, blackstone, sell, lichtenberg, amended, ynys,
# Nearest to zero: two, four, eight, five, migrant, six, est, three,
# Nearest to for: luthor, awarding, navel, outpaced, rence, tabled, spate, serving,
# Nearest to versions: mcgann, processors, homepage, embossed, compilation, diacritics, smartest, irrealism,
# Nearest to something: paintings, knitted, norbert, religiosity, telomeres, creator, eliyahu, people,
# Nearest to existence: thinking, haykal, eminently, accept, anticipated, alleging, landfall, bhfuil,
# Nearest to animals: shapeshifting, algerians, aquatic, touched, hints, fish, pederasty, different,
# Nearest to freedom: empowering, bally, demonstrations, withdrawn, adriaan, tulip, irrespective, girardeau,
# Nearest to event: dimitri, stromata, syndication, sc, flyer, jacobites, ectopic, picturesque,
# Nearest to construction: secrete, moire, dirkjan, hazel, fatality, zilog, rationing, newscaster,
# Nearest to pressure: glycolysis, furlongs, amplification, cdm, wind, gluconeogenesis, kw, oxygen,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2332 0.2038 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2472 0.1996 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2417 0.1984 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1404 0.2014 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1676 0.1997 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1352 0.2006 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1551 0.1973 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2070 0.1995 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1843 0.1967 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1928 0.1982 sec/batch
# Nearest to that: answers, contemplation, oneself, divinity, inconceivable, fractures, constructing, reasons,
# Nearest to more: michinaga, religious, positioning, centimeter, virus, completes, valiant, halfdan,
# Nearest to th: expositor, moyen, constellation, nd, gregorian, deorum, among, kingdoms,
# Nearest to while: widths, cottage, demesne, wresting, biomechanical, undeclared, farm, khwarizmi,
# Nearest to with: snowfall, misfit, quantity, ccj, margrethe, hutchison, sewn, defender,
# Nearest to united: grenville, consultations, sell, veto, blackstone, lichtenberg, amended, largest,
# Nearest to zero: four, two, eight, five, migrant, six, est, three,
# Nearest to for: outpaced, luthor, awarding, navel, emails, rence, gaping, serving,
# Nearest to versions: mcgann, compilation, homepage, embossed, diacritics, processors, smartest, irrealism,
# Nearest to something: paintings, knitted, norbert, religiosity, telomeres, creator, mishearing, placed,
# Nearest to existence: thinking, accept, alleging, haykal, bhfuil, eminently, anticipated, landfall,
# Nearest to animals: shapeshifting, aquatic, algerians, fish, different, touched, hints, pederasty,
# Nearest to freedom: empowering, bally, demonstrations, withdrawn, adriaan, collectivist, traumatic, irrespective,
# Nearest to event: dimitri, stromata, syndication, sc, flyer, professional, picturesque, ectopic,
# Nearest to construction: secrete, hazel, moire, dirkjan, peptides, fatality, accentuate, steppe,
# Nearest to pressure: glycolysis, furlongs, amplification, wind, cdm, gluconeogenesis, oxygen, kw,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1740 0.1998 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2184 0.1995 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1919 0.2018 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1626 0.1999 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1629 0.1973 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1679 0.1987 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1894 0.2011 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1390 0.1965 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1435 0.2002 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2340 0.1972 sec/batch
# Nearest to that: answers, inconceivable, divinity, reasons, contemplation, fractures, coronae, planck,
# Nearest to more: michinaga, religious, centimeter, completes, positioning, valiant, marlboro, virus,
# Nearest to th: expositor, moyen, gregorian, nd, constellation, ojibwe, among, deorum,
# Nearest to while: cottage, demesne, widths, wresting, counsellors, undeclared, hallows, biomechanical,
# Nearest to with: snowfall, misfit, margrethe, quantity, ccj, sewn, hutchison, rojcewicz,
# Nearest to united: grenville, consultations, veto, blackstone, amended, lichtenberg, sell, zanetti,
# Nearest to zero: two, four, five, eight, six, three, migrant, est,
# Nearest to for: outpaced, luthor, awarding, scholastica, spate, emails, philologie, serving,
# Nearest to versions: compilation, mcgann, homepage, diacritics, embossed, and, hobbyist, gadgets,
# Nearest to something: paintings, norbert, knitted, religiosity, telomeres, handedly, mishearing, placed,
# Nearest to existence: thinking, haykal, accept, anticipated, bhfuil, eigenvalues, landfall, speciation,
# Nearest to animals: shapeshifting, algerians, aquatic, fish, fossils, different, diet, touched,
# Nearest to freedom: empowering, bally, demonstrations, irrespective, collectivist, supervises, adriaan, traumatic,
# Nearest to event: dimitri, stromata, sc, flyer, syndication, ectopic, picturesque, lba,
# Nearest to construction: secrete, fatality, peptides, hazel, moire, dirkjan, rationing, steppe,
# Nearest to pressure: furlongs, amplification, glycolysis, cdm, wind, gluconeogenesis, transposing, dissipative,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1813 0.2056 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1833 0.1990 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1724 0.2004 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1891 0.2080 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1570 0.1978 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1199 0.1990 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1579 0.1985 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1349 0.2023 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1891 0.1987 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2181 0.2034 sec/batch
# Nearest to that: answers, reasons, divinity, subordinates, contemplation, inconceivable, abiogenesis, anil,
# Nearest to more: michinaga, religious, valiant, positioning, centimeter, completes, marlboro, halfdan,
# Nearest to th: expositor, gregorian, moyen, ojibwe, deorum, constellation, nd, piazzi,
# Nearest to while: demesne, cottage, wresting, hallows, widths, counsellors, apologize, biomechanical,
# Nearest to with: margrethe, snowfall, misfit, ccj, hutchison, skirmish, fulfilling, andersson,
# Nearest to united: blackstone, grenville, amended, consultations, veto, lichtenberg, nebraska, ynys,
# Nearest to zero: two, four, five, eight, six, three, migrant, nine,
# Nearest to for: outpaced, awarding, tabled, serving, scholastica, luthor, dukakis, rence,
# Nearest to versions: diacritics, mcgann, homepage, compilation, embossed, gadgets, mangaka, illegible,
# Nearest to something: paintings, religiosity, knitted, norbert, placed, handedly, mishearing, telomeres,
# Nearest to existence: landfall, bhfuil, haykal, accept, eminently, bureaucracies, thinking, anticipated,
# Nearest to animals: shapeshifting, aquatic, algerians, fish, heterozygote, breeding, pederasty, pigments,
# Nearest to freedom: empowering, bally, demonstrations, adriaan, collectivist, irrespective, sparing, withdrawn,
# Nearest to event: dimitri, stromata, sc, syndication, flyer, picturesque, ectopic, jacobites,
# Nearest to construction: secrete, fatality, moire, hazel, shrank, vineyards, garda, peptides,
# Nearest to pressure: furlongs, glycolysis, amplification, wind, cdm, gluconeogenesis, transposing, dissipative,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2256 0.2002 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1612 0.2009 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1319 0.1987 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1576 0.1977 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0537 0.2008 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1275 0.2019 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1459 0.1995 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1223 0.1984 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1501 0.0391 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1091 0.1982 sec/batch
# Nearest to that: answers, subordinates, inconceivable, reasons, fractures, hinayana, abiogenesis, divinity,
# Nearest to more: michinaga, religious, centimeter, valiant, positioning, abstracted, lagrand, completes,
# Nearest to th: expositor, gregorian, ojibwe, moyen, nd, centuries, deorum, among,
# Nearest to while: widths, demesne, wresting, counsellors, cottage, hallows, sturt, apologize,
# Nearest to with: snowfall, misfit, quantity, hutchison, sewn, ccj, eos, margrethe,
# Nearest to united: grenville, lichtenberg, consultations, blackstone, nebraska, amended, veto, comply,
# Nearest to zero: two, four, five, eight, six, three, migrant, nine,
# Nearest to for: outpaced, tabled, scholastica, emails, rence, morrissey, serving, awarding,
# Nearest to versions: homepage, compilation, operating, diacritics, mcgann, embossed, gadgets, msx,
# Nearest to something: religiosity, paintings, knitted, placed, telomeres, voltage, harass, norbert,
# Nearest to existence: landfall, bhfuil, bureaucracies, alleging, haykal, crumbled, thinking, accept,
# Nearest to animals: shapeshifting, aquatic, algerians, fish, heterozygote, touched, breeding, different,
# Nearest to freedom: empowering, bally, collectivist, demonstrations, adriaan, irrespective, enhancement, sparing,
# Nearest to event: dimitri, stromata, sc, professional, flyer, syndication, picturesque, jacobites,
# Nearest to construction: secrete, moire, fatality, hazel, vineyards, peptides, shrank, garda,
# Nearest to pressure: furlongs, glycolysis, amplification, wind, cdm, transposing, gluconeogenesis, dissipative,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1024 0.2013 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0503 0.1997 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1204 0.1979 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0381 0.2011 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0700 0.2015 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0335 0.1997 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0842 0.1999 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0849 0.2021 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1349 0.2009 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0366 0.2027 sec/batch
# Nearest to that: subordinates, answers, fractures, inconceivable, hinayana, conceivable, divinity, reasons,
# Nearest to more: michinaga, valiant, religious, centimeter, elastic, promote, positioning, lagrand,
# Nearest to th: expositor, gregorian, ojibwe, nd, moyen, among, centuries, constellation,
# Nearest to while: widths, demesne, cottage, undeclared, counsellors, sturt, hallows, wresting,
# Nearest to with: snowfall, sewn, misfit, quantity, ccj, eos, anvil, second,
# Nearest to united: nebraska, consultations, lichtenberg, grenville, blackstone, veto, largest, thx,
# Nearest to zero: two, four, eight, five, six, three, migrant, one,
# Nearest to for: outpaced, tabled, emails, scholastica, rence, only, serving, a,
# Nearest to versions: homepage, compilation, mcgann, diacritics, operating, launched, aircraft, hobbyist,
# Nearest to something: religiosity, knitted, paintings, placed, telomeres, harass, voltage, cybernetica,
# Nearest to existence: alleging, landfall, bhfuil, bureaucracies, anticipated, accept, eminently, crumbled,
# Nearest to animals: shapeshifting, aquatic, fish, algerians, heterozygote, different, breeding, pederasty,
# Nearest to freedom: empowering, bally, collectivist, adriaan, irrespective, enhancement, demonstrations, personalities,
# Nearest to event: dimitri, stromata, sc, flyer, professional, overtook, tournaments, picturesque,
# Nearest to construction: secrete, moire, fatality, withstand, hazel, shrank, vineyards, peptides,
# Nearest to pressure: glycolysis, wind, furlongs, amplification, cdm, gluconeogenesis, transposing, dissipative,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0477 0.2076 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0338 0.2004 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0231 0.1994 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0620 0.2014 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0680 0.1991 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0335 0.2011 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0753 0.2039 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1039 0.1983 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0723 0.2019 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0541 0.2030 sec/batch
# Nearest to that: answers, divinity, inconceivable, abiogenesis, reasons, fractures, hinayana, formalization,
# Nearest to more: michinaga, valiant, religious, centimeter, positioning, promote, less, lagrand,
# Nearest to th: expositor, ojibwe, gregorian, nd, piazzi, moyen, centuries, among,
# Nearest to while: demesne, undeclared, cottage, widths, counsellors, imprint, anecdote, dogfights,
# Nearest to with: snowfall, quantity, sewn, misfit, ccj, eos, behave, anvil,
# Nearest to united: consultations, lichtenberg, nebraska, zanetti, grenville, amended, blackstone, comply,
# Nearest to zero: two, four, five, eight, six, three, nine, one,
# Nearest to for: outpaced, emails, a, only, deflation, tabled, roadways, scholastica,
# Nearest to versions: compilation, illegible, homepage, diacritics, mcgann, gadgets, launched, aircraft,
# Nearest to something: religiosity, harass, knitted, paintings, placed, colic, sloppy, telomeres,
# Nearest to existence: anticipated, alleging, bhfuil, landfall, haykal, bureaucracies, accept, eminently,
# Nearest to animals: shapeshifting, aquatic, fish, algerians, different, heterozygote, diet, fossils,
# Nearest to freedom: empowering, bally, collectivist, enhancement, adriaan, sparing, personalities, irrespective,
# Nearest to event: dimitri, stromata, sc, flyer, shrimps, professional, tournaments, ectopic,
# Nearest to construction: secrete, moire, withstand, fatality, hazel, shrank, trails, garda,
# Nearest to pressure: glycolysis, amplification, cdm, wind, furlongs, gluconeogenesis, transposing, dissipative,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0355 0.2063 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0878 0.2005 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0680 0.1984 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0371 0.1995 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0635 0.2022 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0701 0.2007 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0699 0.2023 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0479 0.2007 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0759 0.2021 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0806 0.2039 sec/batch
# Nearest to that: divinity, answers, reasons, abiogenesis, hinayana, to, subordinates, inconceivable,
# Nearest to more: valiant, religious, michinaga, elastic, centimeter, halfdan, promote, less,
# Nearest to th: expositor, gregorian, ojibwe, century, nd, centuries, among, moyen,
# Nearest to while: demesne, cottage, widths, hallows, wresting, undeclared, biomechanical, counsellors,
# Nearest to with: sewn, snowfall, eos, quantity, ccj, flugelhorn, andersson, misfit,
# Nearest to united: consultations, grenville, blackstone, lichtenberg, nebraska, thx, zanetti, amended,
# Nearest to zero: two, four, five, eight, six, three, one, nine,
# Nearest to for: outpaced, scholastica, tabled, only, emails, serving, deflation, a,
# Nearest to versions: compilation, homepage, illegible, gadgets, mcgann, diacritics, aircraft, operating,
# Nearest to something: knitted, religiosity, harass, placed, paintings, colic, sloppy, voltage,
# Nearest to existence: landfall, haykal, anticipated, bureaucracies, bhfuil, eminently, alleging, crumbled,
# Nearest to animals: shapeshifting, aquatic, fish, heterozygote, algerians, different, breeding, fossils,
# Nearest to freedom: empowering, collectivist, bally, irrespective, enhancement, adriaan, sparing, personalities,
# Nearest to event: dimitri, stromata, sc, flyer, jacobites, overtook, professional, acp,
# Nearest to construction: secrete, withstand, shrank, moire, fatality, trails, garda, hazel,
# Nearest to pressure: glycolysis, amplification, wind, transposing, furlongs, cdm, dissipative, renewable,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0686 0.2003 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0401 0.1993 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0564 0.1995 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0950 0.2033 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0835 0.2030 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1267 0.1997 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1453 0.2007 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0363 0.2014 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0585 0.1990 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0790 0.2032 sec/batch
# Nearest to that: reasons, abiogenesis, divinity, answers, subordinates, inconceivable, anil, frequency,
# Nearest to more: valiant, michinaga, less, religious, centimeter, halfdan, elastic, promote,
# Nearest to th: expositor, ojibwe, gregorian, century, nd, centuries, piazzi, mathematically,
# Nearest to while: demesne, cottage, widths, counsellors, hallows, wresting, undeclared, sturt,
# Nearest to with: snowfall, sewn, eos, quantity, hutchison, ccj, ory, andersson,
# Nearest to united: consultations, blackstone, nebraska, comply, thx, amended, grenville, veto,
# Nearest to zero: two, four, five, eight, six, three, one, nine,
# Nearest to for: emails, scholastica, outpaced, tabled, serving, only, deflation, morrissey,
# Nearest to versions: compilation, illegible, homepage, diacritics, mcgann, gadgets, operating, reset,
# Nearest to something: knitted, placed, religiosity, harass, voltage, sloppy, colic, telomeres,
# Nearest to existence: landfall, bureaucracies, bhfuil, anticipated, haykal, eminently, accept, alleging,
# Nearest to animals: shapeshifting, aquatic, heterozygote, fish, algerians, fossils, breeding, reap,
# Nearest to freedom: empowering, collectivist, bally, enhancement, adriaan, irrespective, sparing, personalities,
# Nearest to event: dimitri, stromata, sc, flyer, professional, acp, overtook, tournaments,
# Nearest to construction: secrete, withstand, shrank, moire, trails, garda, hazel, ordinary,
# Nearest to pressure: amplification, glycolysis, wind, furlongs, transposing, cdm, dissipative, renewable,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9917 0.2101 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0117 0.2081 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0332 0.2042 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0393 0.2018 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0881 0.2047 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0662 0.1856 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9968 0.2036 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9950 0.2012 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0254 0.2046 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9746 0.2007 sec/batch
# Nearest to that: abiogenesis, reasons, so, subordinates, answers, to, divinity, frequency,
# Nearest to more: valiant, less, religious, michinaga, halfdan, elastic, centimeter, assimilated,
# Nearest to th: expositor, gregorian, nd, ojibwe, century, piazzi, centuries, juche,
# Nearest to while: demesne, counsellors, cottage, widths, undeclared, anecdote, hallows, wresting,
# Nearest to with: snowfall, sewn, quantity, anvil, eos, flugelhorn, hutchison, fulfilling,
# Nearest to united: consultations, grenville, nebraska, thx, blackstone, lichtenberg, parkman, amended,
# Nearest to zero: two, four, five, six, eight, three, one, nine,
# Nearest to for: emails, scholastica, tabled, only, a, serving, deflation, bundesverfassungsgericht,
# Nearest to versions: compilation, illegible, operating, version, aircraft, launched, homepage, reset,
# Nearest to something: religiosity, knitted, harass, placed, colic, sloppy, telomeres, voltage,
# Nearest to existence: bureaucracies, landfall, anticipated, eminently, haykal, accept, crumbled, alleging,
# Nearest to animals: shapeshifting, heterozygote, algerians, aquatic, pederasty, fish, different, reap,
# Nearest to freedom: empowering, collectivist, bally, enhancement, sparing, adriaan, personalities, irrespective,
# Nearest to event: dimitri, stromata, sc, jacobites, overtook, professional, tournaments, competition,
# Nearest to construction: withstand, moire, shrank, trails, secrete, quarried, important, garda,
# Nearest to pressure: amplification, glycolysis, furlongs, transposing, renewable, cdm, wind, dissipative,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9854 0.2028 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9344 0.2059 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0141 0.2023 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0052 0.2016 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0254 0.2048 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9814 0.2050 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9147 0.2006 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9713 0.2083 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9481 0.2034 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9883 0.1982 sec/batch
# Nearest to that: subordinates, answers, to, divinity, so, reasons, abiogenesis, frequency,
# Nearest to more: less, valiant, religious, have, elastic, michinaga, centimeter, halfdan,
# Nearest to th: expositor, nd, gregorian, century, ojibwe, centuries, piazzi, among,
# Nearest to while: widths, cottage, undeclared, demesne, doubling, anecdote, counsellors, biomechanical,
# Nearest to with: snowfall, sewn, eos, quantity, flugelhorn, aragon, fulfilling, anvil,
# Nearest to united: consultations, thx, nebraska, amended, comply, blackstone, lichtenberg, wrestling,
# Nearest to zero: two, four, five, eight, six, three, one, nine,
# Nearest to for: a, emails, only, scholastica, the, outpaced, storing, deflation,
# Nearest to versions: illegible, aircraft, compilation, homepage, launched, version, mingw, mangaka,
# Nearest to something: knitted, religiosity, placed, harass, voltage, sloppy, colic, translates,
# Nearest to existence: anticipated, alleging, landfall, bureaucracies, eminently, americano, crumbled, haykal,
# Nearest to animals: shapeshifting, heterozygote, aquatic, algerians, fish, pederasty, different, marsupials,
# Nearest to freedom: empowering, collectivist, bally, enhancement, adriaan, irrespective, sparing, personalities,
# Nearest to event: dimitri, stromata, sc, overtook, tournaments, jacobites, lba, flyer,
# Nearest to construction: moire, withstand, important, shrank, trails, ordinary, basel, secrete,
# Nearest to pressure: glycolysis, amplification, wind, cdm, furlongs, gluconeogenesis, transposing, renewable,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9775 0.2031 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0204 0.2069 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9964 0.2019 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0071 0.2019 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0493 0.2023 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9598 0.2028 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9958 0.2069 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9762 0.2006 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9755 0.2026 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9976 0.2016 sec/batch
# Nearest to that: to, divinity, reasons, answers, subordinates, is, abiogenesis, so,
# Nearest to more: valiant, less, religious, elastic, have, michinaga, stitching, halfdan,
# Nearest to th: expositor, nd, gregorian, century, ojibwe, centuries, piazzi, sixth,
# Nearest to while: widths, cottage, demesne, anecdote, undeclared, doubling, poetry, roads,
# Nearest to with: sewn, snowfall, eos, flugelhorn, quantity, hutchison, fulfilling, the,
# Nearest to united: thx, blackstone, consultations, zanetti, parkman, nebraska, amended, lichtenberg,
# Nearest to zero: two, four, five, six, eight, three, one, nine,
# Nearest to for: emails, a, only, the, scholastica, deflation, tabled, storing,
# Nearest to versions: illegible, aircraft, compilation, mingw, version, diacritics, mcgann, gadgets,
# Nearest to something: knitted, harass, religiosity, sloppy, placed, colic, voltage, koenig,
# Nearest to existence: anticipated, alleging, landfall, bureaucracies, dharmakirti, haykal, bhfuil, possibility,
# Nearest to animals: shapeshifting, heterozygote, algerians, aquatic, different, marsupials, spongiform, thaliana,
# Nearest to freedom: empowering, collectivist, bally, enhancement, irrespective, sparing, adriaan, recipients,
# Nearest to event: dimitri, stromata, sc, shrimps, lba, tournaments, taken, overtook,
# Nearest to construction: moire, withstand, ordinary, trails, engineering, garda, important, shrank,
# Nearest to pressure: amplification, glycolysis, wind, transposing, furlongs, dissipative, cdm, gluconeogenesis,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0015 0.2048 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9752 0.2012 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9892 0.1986 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9995 0.2056 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0121 0.2039 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0107 0.1968 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9712 0.1977 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9574 0.2011 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9704 0.1939 sec/batch
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8891 0.2000 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9012 0.2010 sec/batch
# Nearest to that: be, to, it, not, is, this, been, so,
# Nearest to more: less, than, have, valiant, are, elastic, many, generally,
# Nearest to th: century, nd, centuries, expositor, date, st, gregorian, hdi,
# Nearest to while: a, daniels, founding, he, undeclared, doubling, anecdote, dee,
# Nearest to with: the, as, and, in, a, of, along, is,
# Nearest to united: states, cedric, mansfield, abbreviated, america, war, comply, esoc,
# Nearest to zero: two, four, five, six, three, eight, one, nine,
# Nearest to for: a, the, only, and, to, in, see, of,
# Nearest to versions: illegible, version, aircraft, gimpshop, mcgann, reset, operating, compilation,
# Nearest to something: harass, sloppy, koenig, mr, colic, pathological, contacted, placed,
# Nearest to existence: alleging, possibility, offbeat, dharmakirti, bureaucracies, nabba, essence, jacksonian,
# Nearest to animals: spongiform, reap, infiltrated, persecutor, pasteur, ucmp, vicugna, moral,
# Nearest to freedom: recipients, popmatters, boyd, empowering, penwith, collectivist, dirge, sparing,
# Nearest to event: events, sc, stromata, february, dimitri, held, extinction, quilt,
# Nearest to construction: quarried, basel, ampex, pierpont, withstand, cappella, shrank, farming,
# Nearest to pressure: glycolysis, transposing, isobaric, dissipative, wind, amplification, renewable, rea,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8348 0.2045 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8468 0.2108 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8211 0.1993 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8507 0.2009 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8665 0.2035 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8769 0.2005 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8760 0.2021 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8494 0.2073 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8771 0.2122 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8510 0.2091 sec/batch
# Nearest to that: be, to, it, so, not, some, is, this,
# Nearest to more: than, valiant, less, have, are, elastic, europeans, generally,
# Nearest to th: century, centuries, nd, date, hdi, expositor, late, st,
# Nearest to while: daniels, doubling, founding, particularly, a, undeclared, dee, having,
# Nearest to with: as, the, of, in, and, a, sewn, along,
# Nearest to united: states, cedric, war, america, mansfield, abbreviated, laia, opens,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, the, only, to, in, and, see, of,
# Nearest to versions: illegible, version, aircraft, gimpshop, mcgann, compilation, operating, reset,
# Nearest to something: harass, sloppy, koenig, mr, placed, knitted, shine, colic,
# Nearest to existence: alleging, possibility, dharmakirti, offbeat, essence, gleichschaltung, profusion, triad,
# Nearest to animals: spongiform, reap, ucmp, different, vicugna, infiltrated, pigs, persecutor,
# Nearest to freedom: recipients, empowering, popmatters, boyd, collectivist, penwith, vesque, guaranteed,
# Nearest to event: events, sc, stromata, dimitri, extinction, february, held, quilt,
# Nearest to construction: quarried, basel, ampex, pierpont, pneuma, subdomain, built, cappella,
# Nearest to pressure: transposing, glycolysis, dissipative, isobaric, wind, amplification, renewable, rea,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8745 0.2171 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8496 0.2087 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8412 0.2071 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8164 0.2084 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9163 0.2120 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8430 0.2161 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9791 0.2122 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8672 0.2097 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9289 0.2066 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8234 0.2136 sec/batch
# Nearest to that: to, not, be, it, this, is, so, been,
# Nearest to more: than, less, valiant, have, elastic, are, generally, europeans,
# Nearest to th: century, centuries, nd, date, expositor, early, hdi, late,
# Nearest to while: he, a, daniels, founding, doubling, having, successfully, undeclared,
# Nearest to with: as, the, in, and, of, a, along, to,
# Nearest to united: states, war, cedric, mansfield, opens, laia, america, comply,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, to, only, the, and, in, emails, of,
# Nearest to versions: illegible, aircraft, version, gimpshop, mcgann, compilation, operating, mk,
# Nearest to something: mr, harass, sloppy, colic, koenig, knitted, placed, would,
# Nearest to existence: alleging, possibility, dharmakirti, triad, gleichschaltung, profusion, essence, offbeat,
# Nearest to animals: spongiform, reap, ucmp, vicugna, infiltrated, pasteur, different, pigs,
# Nearest to freedom: recipients, empowering, popmatters, boyd, collectivist, penwith, enhancement, dirge,
# Nearest to event: sc, events, dimitri, february, stromata, extinction, held, syndication,
# Nearest to construction: basel, quarried, pierpont, ampex, prompted, pneuma, cappella, subdomain,
# Nearest to pressure: transposing, isobaric, glycolysis, dissipative, wind, dunraven, amplification, renewable,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7562 0.2107 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8743 0.2091 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7900 0.2080 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8632 0.2028 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8493 0.1992 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8309 0.2006 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8904 0.1143 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8212 0.2007 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8268 0.2006 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8440 0.2004 sec/batch
# Nearest to that: to, be, this, it, been, some, not, is,
# Nearest to more: than, valiant, less, have, elastic, are, jardines, contribution,
# Nearest to th: century, centuries, nd, date, early, late, st, expositor,
# Nearest to while: a, he, founding, daniels, particularly, in, anecdote, undeclared,
# Nearest to with: of, the, along, a, in, as, and, sewn,
# Nearest to united: states, war, cedric, opens, mansfield, arno, laia, medal,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, to, the, only, in, and, emails, of,
# Nearest to versions: illegible, version, aircraft, gimpshop, compilation, operating, mcgann, mk,
# Nearest to something: harass, mr, colic, sloppy, knitted, placed, koenig, would,
# Nearest to existence: alleging, possibility, dharmakirti, hierocles, triad, bureaucracies, offbeat, essence,
# Nearest to animals: spongiform, reap, infiltrated, ucmp, vicugna, pasteur, joy, different,
# Nearest to freedom: recipients, empowering, popmatters, boyd, penwith, collectivist, dirge, enhancement,
# Nearest to event: sc, events, stromata, dimitri, extinction, february, held, victims,
# Nearest to construction: quarried, basel, ampex, pierpont, prompted, cappella, taifa, transportation,
# Nearest to pressure: transposing, isobaric, dissipative, glycolysis, amplification, wind, dunraven, rea,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8058 0.2020 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8246 0.2009 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8316 0.2008 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7965 0.2011 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8414 0.1991 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8445 0.1997 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8723 0.2006 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7456 0.2011 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7981 0.2000 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8034 0.1989 sec/batch
# Nearest to that: be, to, this, not, it, some, is, so,
# Nearest to more: than, have, less, are, valiant, elastic, many, generally,
# Nearest to th: century, centuries, nd, late, early, date, st, expositor,
# Nearest to while: he, a, daniels, founding, undeclared, in, passionately, distinguished,
# Nearest to with: in, as, of, a, the, and, for, along,
# Nearest to united: states, war, laia, cedric, countries, opens, america, abbreviated,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, the, to, in, and, only, of, given,
# Nearest to versions: illegible, version, aircraft, gimpshop, mcgann, operating, compilation, mk,
# Nearest to something: harass, sloppy, koenig, mr, knitted, colic, would, placed,
# Nearest to existence: alleging, possibility, hierocles, offbeat, dharmakirti, bureaucracies, profusion, unimpressed,
# Nearest to animals: reap, infiltrated, spongiform, ucmp, persecutor, vicugna, pasteur, moral,
# Nearest to freedom: recipients, popmatters, empowering, penwith, boyd, dirge, enhancement, vesque,
# Nearest to event: events, sc, held, february, stromata, dimitri, victims, extinction,
# Nearest to construction: quarried, basel, ampex, pierpont, prompted, frege, taifa, corridors,
# Nearest to pressure: isobaric, transposing, glycolysis, dissipative, pressures, wind, renewable, cpsu,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7407 0.2046 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8251 0.2006 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8342 0.1998 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8422 0.2083 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8196 0.2111 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9070 0.2108 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8416 0.2144 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8124 0.2101 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8318 0.2074 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8345 0.2160 sec/batch
# Nearest to that: to, be, not, it, this, is, some, have,
# Nearest to more: than, less, have, are, valiant, elastic, other, for,
# Nearest to th: century, centuries, nd, late, st, date, early, hdi,
# Nearest to while: a, he, daniels, undeclared, particularly, founding, grew, powerhouse,
# Nearest to with: the, as, of, and, in, a, along, for,
# Nearest to united: states, war, countries, laia, america, cedric, nations, abbreviated,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, the, to, and, only, of, in, also,
# Nearest to versions: illegible, version, aircraft, gimpshop, mcgann, compilation, reset, operating,
# Nearest to something: harass, sloppy, would, koenig, mr, placed, knitted, colic,
# Nearest to existence: alleging, possibility, dharmakirti, essence, hierocles, profusion, offbeat, triad,
# Nearest to animals: reap, spongiform, infiltrated, ucmp, persecutor, vicugna, pasteur, fierce,
# Nearest to freedom: recipients, empowering, popmatters, boyd, penwith, collectivist, spingarn, enhancement,
# Nearest to event: events, sc, extinction, dimitri, february, stromata, held, quilt,
# Nearest to construction: quarried, basel, pierpont, ampex, taifa, frege, cappella, shrank,
# Nearest to pressure: transposing, isobaric, dissipative, glycolysis, pressures, amplification, renewable, cpsu,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8859 0.2098 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8340 0.2100 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8160 0.2097 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8619 0.2073 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8600 0.2090 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8542 0.2177 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8207 0.2126 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8288 0.2083 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7903 0.2113 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7998 0.2092 sec/batch
# Nearest to that: to, be, this, is, not, it, so, which,
# Nearest to more: than, less, have, valiant, are, elastic, even, jardines,
# Nearest to th: century, centuries, nd, early, date, late, st, hdi,
# Nearest to while: a, he, successfully, daniels, particularly, grew, undeclared, in,
# Nearest to with: of, as, in, the, and, a, to, along,
# Nearest to united: states, war, laia, america, countries, cedric, nations, known,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, to, only, the, and, in, are, also,
# Nearest to versions: illegible, version, aircraft, gimpshop, operating, compilation, reset, mcgann,
# Nearest to something: harass, sloppy, mr, koenig, placed, colic, knitted, would,
# Nearest to existence: alleging, possibility, profusion, dharmakirti, triad, hierocles, essence, offbeat,
# Nearest to animals: infiltrated, reap, spongiform, different, ucmp, vicugna, pasteur, persecutor,
# Nearest to freedom: recipients, empowering, boyd, popmatters, penwith, collectivist, dirge, spingarn,
# Nearest to event: events, sc, extinction, february, held, dimitri, stromata, victims,
# Nearest to construction: quarried, basel, ampex, pierpont, built, prompted, pneuma, shrank,
# Nearest to pressure: transposing, isobaric, glycolysis, dissipative, pressures, renewable, cpsu, rea,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8408 0.2159 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8439 0.2115 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9368 0.2126 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9262 0.2019 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8764 0.2010 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8523 0.2003 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7792 0.1983 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8387 0.1990 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7264 0.2011 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8816 0.2016 sec/batch
# Nearest to that: be, to, this, not, it, is, which, so,
# Nearest to more: than, less, have, valiant, are, elastic, better, accommodates,
# Nearest to th: century, centuries, nd, early, date, gregorian, hdi, expositor,
# Nearest to while: he, a, daniels, successfully, founding, undeclared, grew, powerhouse,
# Nearest to with: of, the, and, as, in, a, along, to,
# Nearest to united: states, war, opens, laia, cedric, america, countries, us,
# Nearest to zero: two, four, five, six, three, one, eight, nine,
# Nearest to for: a, to, the, and, only, in, or, of,
# Nearest to versions: illegible, version, compilation, aircraft, gimpshop, operating, mcgann, mingw,
# Nearest to something: sloppy, harass, mr, would, koenig, placed, colic, just,
# Nearest to existence: alleging, possibility, profusion, dharmakirti, joplin, essence, nabba, hierocles,
# Nearest to animals: reap, infiltrated, pasteur, spongiform, vicugna, ucmp, persecutor, different,
# Nearest to freedom: recipients, empowering, popmatters, penwith, boyd, spingarn, dirge, guaranteed,
# Nearest to event: events, sc, dimitri, february, held, extinction, victims, stromata,
# Nearest to construction: quarried, basel, ampex, pneuma, prompted, pierpont, frege, farming,
# Nearest to pressure: isobaric, transposing, glycolysis, dissipative, pressures, renewable, headquarters, rea,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8482 0.2035 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8227 0.2007 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
